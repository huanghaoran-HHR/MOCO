# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1,2"  # 使用第0和第1号GPU

# %%
gpu_info = !nvidia-smi -i 1,2
gpu_info = '\n'.join(gpu_info)
print(gpu_info)

from datetime import datetime
from functools import partial
from PIL import Image
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CIFAR10
from torchvision.models import resnet
from tqdm import tqdm
import argparse
import json
import math
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# Thu Apr 10 09:22:09 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.146.02             Driver Version: 535.146.02   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   1  NVIDIA GeForce RTX 4080        Off | 00000000:3E:00.0 Off |                  N/A |
# | 30%   34C    P8              11W / 320W |      3MiB / 16376MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce RTX 4080        Off | 00000000:88:00.0 Off |                  N/A |
# | 30%   30C    P8              11W / 320W |      3MiB / 16376MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
parser = argparse.ArgumentParser(description='Train MoCo on CIFAR-10')

parser.add_argument('-a', '--arch', default='resnet18')

# lr: 0.06 for batch 512 (or 0.03 for batch 256)
parser.add_argument('--lr', '--learning-rate', default=0.01, type=float, metavar='LR', help='initial learning rate', dest='lr')
parser.add_argument('--epochs', default=200, type=int, metavar='N', help='number of total epochs to run')
parser.add_argument('--schedule', default=[120, 160], nargs='*', type=int, help='learning rate schedule (when to drop lr by 10x); does not take effect if --cos is on')
parser.add_argument('--cos', action='store_true', help='use cosine lr schedule')

parser.add_argument('--batch-size', default=512, type=int, metavar='N', help='mini-batch size')
parser.add_argument('--wd', default=5e-4, type=float, metavar='W', help='weight decay')

# moco specific configs:
parser.add_argument('--moco-dim', default=128, type=int, help='feature dimension')
parser.add_argument('--moco-k', default=4096, type=int, help='queue size; number of negative keys')
parser.add_argument('--moco-m', default=0.99, type=float, help='moco momentum of updating key encoder')
parser.add_argument('--moco-t', default=0.1, type=float, help='softmax temperature')

parser.add_argument('--bn-splits', default=8, type=int, help='simulate multi-gpu behavior of BatchNorm in one gpu; 1 is SyncBatchNorm in multi-gpu')

parser.add_argument('--symmetric', action='store_true', help='use a symmetric loss function that backprops to both crops')

# knn monitor
parser.add_argument('--knn-k', default=200, type=int, help='k in kNN monitor')
parser.add_argument('--knn-t', default=0.1, type=float, help='softmax temperature in kNN monitor; could be different with moco-t')

# utils
parser.add_argument('--resume', default='', type=str, metavar='PATH', help='path to latest checkpoint (default: none)')
parser.add_argument('--results-dir', default='', type=str, metavar='PATH', help='path to cache (default: none)')

'''
args = parser.parse_args()  # running in command line
'''
args = parser.parse_args('')  # running in ipynb

# set command line arguments here when running in ipynb
args.epochs = 200
args.cos = False
args.schedule = []  # cos in use
args.symmetric = False
if args.results_dir == '':
    args.results_dir = '/home/lab-huang.haoran/moco_flowers/cache-' + datetime.now().strftime("%Y-%m-%d-%H-%M-%S-moco")

print(args)
# Out:
# Namespace(arch='resnet18', lr=0.01, epochs=200, schedule=[], cos=False, batch_size=512, wd=0.0005, moco_dim=128, moco_k=4096, moco_m=0.99, moco_t=0.1, bn_splits=8, symmetric=False, knn_k=200, knn_t=0.1, resume='', results_dir='/home/lab-huang.haoran/moco_flowers/cache-2025-04-10-09-22-16-moco')

# %% [markdown]
# ### Define data loaders

# %%
class CIFAR10Pair(CIFAR10):
    """CIFAR10 Dataset.
    """
    def __getitem__(self, index):
        img = self.data[index]
        img = Image.fromarray(img)

        if self.transform is not None:
            im_1 = self.transform(img)
            im_2 = self.transform(img)

        return im_1, im_2

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(32),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])])

# data prepare
train_data = CIFAR10Pair(root='data', train=True, transform=train_transform, download=True)
train_loader = DataLoader(train_data, batch_size=args.batch_size, shuffle=True, num_workers=16, pin_memory=True, drop_last=True)

memory_data = CIFAR10(root='data', train=True, transform=test_transform, download=True)
memory_loader = DataLoader(memory_data, batch_size=args.batch_size, shuffle=False, num_workers=16, pin_memory=True)

test_data = CIFAR10(root='data', train=False, transform=test_transform, download=True)
test_loader = DataLoader(test_data, batch_size=args.batch_size, shuffle=False, num_workers=16, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Define base encoder

# %%
# SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension
# implementation adapted from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py
class SplitBatchNorm(nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W), running_mean_split, running_var_split,
                self.weight.repeat(self.num_splits), self.bias.repeat(self.num_splits),
                True, self.momentum, self.eps).view(N, C, H, W)
            self.running_mean.data.copy_(running_mean_split.view(self.num_splits, C).mean(dim=0))
            self.running_var.data.copy_(running_var_split.view(self.num_splits, C).mean(dim=0))
            return outcome
        else:
            return nn.functional.batch_norm(
                input, self.running_mean, self.running_var,
                self.weight, self.bias, False, self.momentum, self.eps)

class ModelBase(nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """
    def __init__(self, feature_dim=128, arch=None, bn_splits=16):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = partial(SplitBatchNorm, num_splits=bn_splits) if bn_splits > 1 else nn.BatchNorm2d
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == 'conv1':
                module = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
            if isinstance(module, nn.MaxPool2d):
                continue
            if isinstance(module, nn.Linear):
                self.net.append(nn.Flatten(1))
            self.net.append(module)

        self.net = nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x

# %% [markdown]
# ### Define MoCo wrapper

# %%
class ModelMoCo(nn.Module):
    def __init__(self, dim=128, K=4096, m=0.99, T=0.1, arch='resnet18', bn_splits=8, symmetric=True):
        super(ModelMoCo, self).__init__()

        self.K = K
        self.m = m
        self.T = T
        self.symmetric = symmetric

        # create the encoders
        self.encoder_q = ModelBase(feature_dim=dim, arch=arch, bn_splits=bn_splits)
        self.encoder_k = ModelBase(feature_dim=dim, arch=arch, bn_splits=bn_splits)

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient

        # create the queue
        self.register_buffer("queue", torch.randn(dim, K))
        self.queue = nn.functional.normalize(self.queue, dim=0)

        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        """
        Momentum update of the key encoder
        """
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        batch_size = keys.shape[0]

        ptr = int(self.queue_ptr)
        assert self.K % batch_size == 0  # for simplicity

        # replace the keys at ptr (dequeue and enqueue)
        self.queue[:, ptr:ptr + batch_size] = keys.t()  # transpose
        ptr = (ptr + batch_size) % self.K  # move pointer

        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_single_gpu(self, x):
        """
        Batch shuffle, for making use of BatchNorm.
        """
        # random shuffle index
        idx_shuffle = torch.randperm(x.shape[0]).cuda()

        # index for restoring
        idx_unshuffle = torch.argsort(idx_shuffle)

        return x[idx_shuffle], idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_single_gpu(self, x, idx_unshuffle):
        """
        Undo batch shuffle.
        """
        return x[idx_unshuffle]

    def contrastive_loss(self, im_q, im_k):
        # compute query features
        q = self.encoder_q(im_q)  # queries: NxC
        q = nn.functional.normalize(q, dim=1)  # already normalized

        # compute key features
        with torch.no_grad():  # no gradient to keys
            # shuffle for making use of BN
            im_k_, idx_unshuffle = self._batch_shuffle_single_gpu(im_k)

            k = self.encoder_k(im_k_)  # keys: NxC
            k = nn.functional.normalize(k, dim=1)  # already normalized

            # undo shuffle
            k = self._batch_unshuffle_single_gpu(k, idx_unshuffle)

        # compute logits
        # Einstein sum is more intuitive
        # positive logits: Nx1
        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        # negative logits: NxK
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach()])

        # logits: Nx(1+K)
        logits = torch.cat([l_pos, l_neg], dim=1)

        # apply temperature
        logits /= self.T

        # labels: positive key indicators
        labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()

        loss = nn.CrossEntropyLoss().cuda()(logits, labels)

        return loss, q, k

    def forward(self, im1, im2):
        """
        Input:
            im_q: a batch of query images
            im_k: a batch of key images
        Output:
            loss
        """

        # update the key encoder
        with torch.no_grad():  # no gradient to keys
            self._momentum_update_key_encoder()

        # compute loss
        if self.symmetric:  # asymmetric loss
            loss_12, q1, k2 = self.contrastive_loss(im1, im2)
            loss_21, q2, k1 = self.contrastive_loss(im2, im1)
            loss = loss_12 + loss_21
            k = torch.cat([k1, k2], dim=0)
        else:  # asymmetric loss
            loss, q, k = self.contrastive_loss(im1, im2)

        self._dequeue_and_enqueue(k)

        return loss

  # create model
model = ModelMoCo(
        dim=args.moco_dim,
        K=args.moco_k,
        m=args.moco_m,
        T=args.moco_t,
        arch=args.arch,
        bn_splits=args.bn_splits,
        symmetric=args.symmetric,
    ).cuda()

print(model.encoder_q)
# Out:
# ModelBase(
#   (net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): AdaptiveAvgPool2d(output_size=(1, 1))
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=512, out_features=128, bias=True)
#   )
# )

# %% [markdown]
# ### Define train/test

# %%
# train for one epoch
def train(net, data_loader, train_optimizer, epoch, args):
    net.train()
    adjust_learning_rate(optimizer, epoch, args)

    total_loss, total_num, train_bar = 0.0, 0, tqdm(data_loader)
    for im_1, im_2 in train_bar:
        im_1, im_2 = im_1.cuda(non_blocking=True), im_2.cuda(non_blocking=True)

        loss = net(im_1, im_2)

        train_optimizer.zero_grad()
        loss.backward()
        train_optimizer.step()

        total_num += data_loader.batch_size
        total_loss += loss.item() * data_loader.batch_size
        train_bar.set_description('Train Epoch: [{}/{}], lr: {:.6f}, Loss: {:.4f}'.format(epoch, args.epochs, optimizer.param_groups[0]['lr'], total_loss / total_num))

    return total_loss / total_num

# lr scheduler for training
def adjust_learning_rate(optimizer, epoch, args):
    """Decay the learning rate based on schedule"""
    lr = args.lr
    if args.cos:  # cosine lr schedule
        lr *= 0.5 * (1. + math.cos(math.pi * epoch / args.epochs))
    else:  # stepwise lr schedule
        for milestone in args.schedule:
            lr *= 0.1 if epoch >= milestone else 1.
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
# test using a knn monitor
def test(net, memory_data_loader, test_data_loader, epoch, args):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_top5, total_num, feature_bank = 0.0, 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc='Feature extracting'):
            feature = net(data.cuda(non_blocking=True))
            feature = F.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(memory_data_loader.dataset.targets, device=feature_bank.device)
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = F.normalize(feature, dim=1)

            pred_labels = knn_predict(feature, feature_bank, feature_labels, classes, args.knn_k, args.knn_t)

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            test_bar.set_description('Test Epoch: [{}/{}] Acc@1:{:.2f}%'.format(epoch, args.epochs, total_top1 / total_num * 100))

    return total_top1 / total_num * 100

# knn monitor as in InstDisc https://arxiv.org/abs/1805.01978
# implementation follows http://github.com/zhirongw/lemniscate.pytorch and https://github.com/leftthomas/SimCLR
def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices)
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(feature.size(0) * knn_k, classes, device=sim_labels.device)
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(dim=-1, index=sim_labels.view(-1, 1), value=1.0)
    # weighted score ---> [B, C]
    pred_scores = torch.sum(one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1), dim=1)

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ### Start training

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1,2"  # 使用第0和第1号GPU
# define optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.wd, momentum=0.9)

# load model if resume
epoch_start = 1
if args.resume is not '':
    checkpoint = torch.load(args.resume)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    epoch_start = checkpoint['epoch'] + 1
    print('Loaded from: {}'.format(args.resume))

# logging
results = {'train_loss': [], 'test_acc@1': []}
if not os.path.exists(args.results_dir):
    os.mkdir(args.results_dir)
# dump args
with open(args.results_dir + '/args.json', 'w') as fid:
    json.dump(args.__dict__, fid, indent=2)

# training loop
for epoch in range(epoch_start, args.epochs + 1):
    train_loss = train(model, train_loader, optimizer, epoch, args)
    results['train_loss'].append(train_loss)
    test_acc_1 = test(model.encoder_q, memory_loader, test_loader, epoch, args)
    results['test_acc@1'].append(test_acc_1)
    # save statistics
    data_frame = pd.DataFrame(data=results, index=range(epoch_start, epoch + 1))
    data_frame.to_csv(args.results_dir + '/log.csv', index_label='epoch')
    # save model
    torch.save({'epoch': epoch, 'state_dict': model.state_dict(), 'optimizer' : optimizer.state_dict(),}, args.results_dir + '/model_last.pth')
# Out:
# <>:8: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:8: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /tmp/ipykernel_230528/558445218.py:8: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if args.resume is not '':
# Train Epoch: [1/200], lr: 0.010000, Loss: 7.4309: 100%|██████████| 97/97 [00:19<00:00,  5.09it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 30.29it/s]
# Test Epoch: [1/200] Acc@1:38.14%: 100%|██████████| 20/20 [00:01<00:00, 11.21it/s]
# Train Epoch: [2/200], lr: 0.010000, Loss: 6.8492: 100%|██████████| 97/97 [00:15<00:00,  6.15it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 32.46it/s]
# Test Epoch: [2/200] Acc@1:43.13%: 100%|██████████| 20/20 [00:01<00:00, 15.51it/s]
# Train Epoch: [3/200], lr: 0.010000, Loss: 6.6067: 100%|██████████| 97/97 [00:15<00:00,  6.38it/s]
# Feature extracting: 100%|██████████| 98/98 [00:02<00:00, 32.92it/s]
# Test Epoch: [3/200] Acc@1:45.72%: 100%|██████████| 20/20 [00:01<00:00, 15.02it/s]
# Train Epoch: [4/200], lr: 0.010000, Loss: 6.4112: 100%|██████████| 97/97 [00:15<00:00,  6.29it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 31.62it/s]
# Test Epoch: [4/200] Acc@1:48.13%: 100%|██████████| 20/20 [00:01<00:00, 15.83it/s]
# Train Epoch: [5/200], lr: 0.010000, Loss: 6.2290: 100%|██████████| 97/97 [00:15<00:00,  6.35it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 31
/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 31.77it/s]
# Test Epoch: [197/200] Acc@1:77.75%: 100%|██████████| 20/20 [00:01<00:00, 15.22it/s]
# Train Epoch: [198/200], lr: 0.010000, Loss: 2.7099: 100%|██████████| 97/97 [00:15<00:00,  6.20it/s]
# Feature extracting: 100%|██████████| 98/98 [00:02<00:00, 33.18it/s]
# Test Epoch: [198/200] Acc@1:78.48%: 100%|██████████| 20/20 [00:01<00:00, 16.78it/s]
# Train Epoch: [199/200], lr: 0.010000, Loss: 2.6729: 100%|██████████| 97/97 [00:15<00:00,  6.34it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 32.24it/s]
# Test Epoch: [199/200] Acc@1:77.89%: 100%|██████████| 20/20 [00:01<00:00, 15.90it/s]
# Train Epoch: [200/200], lr: 0.010000, Loss: 2.6851: 100%|██████████| 97/97 [00:15<00:00,  6.38it/s]
# Feature extracting: 100%|██████████| 98/98 [00:03<00:00, 31.90it/s]
# Test Epoch: [200/200] Acc@1:78.01%: 100%|██████████| 20/20 [00:01<00:00, 14.99it/s]

# %%
#使用谷歌云盘
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import csv

def test(net, memory_data_loader, test_data_loader, epoch, args):
    net.eval()
    # 获取CIFAR-10的类别名称
    class_names = memory_data_loader.dataset.classes
    classes = len(class_names)

    total_top1, total_num = 0.0, 0
    feature_bank = []
    results = []  # 用于存储每张图片的记录（索引、真实标签名称、预测标签名称）
    global_index = 0

    with torch.no_grad():
        # 生成特征库
        for data, _ in tqdm(memory_data_loader, desc='Feature extracting'):
            data = data.cuda(non_blocking=True)
            feature = net(data)
            feature = F.normalize(feature, dim=1)
            feature_bank.append(feature)
        # 拼接所有特征，并转置为 [D, N] 的矩阵
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # 获取内存数据集的标签（这里得到的是数字标签）
        feature_labels = torch.tensor(memory_data_loader.dataset.targets, device=feature_bank.device)

        # 对测试数据集进行 k-NN 预测
        test_bar = tqdm(test_data_loader, desc='Testing')
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = F.normalize(feature, dim=1)

            pred_labels = knn_predict(feature, feature_bank, feature_labels, classes, args.knn_k, args.knn_t)
            # pred_labels[:, 0] 为 top1 预测标签（数字）
            batch_pred = pred_labels[:, 0]

            total_num += data.size(0)
            total_top1 += (batch_pred == target).float().sum().item()

            # 将当前 batch 的预测结果及真实标签记录下来
            batch_true = target.cpu().tolist()
            batch_pred = batch_pred.cpu().tolist()
            for i in range(len(batch_true)):
                true_label_name = class_names[ batch_true[i] ]
                pred_label_name = class_names[ batch_pred[i] ]
                results.append({
                    "index": global_index,
                    "true": true_label_name,
                    "pred": pred_label_name
                })
                # 输出每张图片的标签，按照格式要求
                print(f"第{global_index + 1}张图片：预测名称是“{pred_label_name}”，实际名称是“{true_label_name}”")
                global_index += 1

            test_bar.set_description('Test Epoch: Acc@1: {:.2f}%'.format(total_top1 / total_num * 100))

    accuracy = total_top1 / total_num * 100
    print("Test Accuracy: {:.2f}%".format(accuracy))

    # 将结果写入 CSV 文件
    csv_file = "test_results.csv"
    with open(csv_file, "w", newline="") as f:
        fieldnames = ["index", "true", "pred"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    print("预测结果已保存到", csv_file)

    return accuracy, results

def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # 计算每个特征向量与特征库中所有特征的余弦相似度 ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # 取出 top-k 相似度 ---> [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # 根据 top-k 索引获取对应标签 ---> [B, K]
    sim_labels = torch.gather(feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices)
    sim_weight = (sim_weight / knn_t).exp()

    # 构造 one-hot 标签，并统计每个类别的加权分数
    one_hot_label = torch.zeros(feature.size(0) * knn_k, classes, device=sim_labels.device)
    one_hot_label = one_hot_label.scatter(dim=-1, index=sim_labels.view(-1, 1), value=1.0)
    pred_scores = torch.sum(one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1), dim=1)
    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels


# 构建模型并加载权重
model = ModelMoCo(
    dim=args.moco_dim,
    K=args.moco_k,
    m=args.moco_m,
    T=args.moco_t,
    arch=args.arch,
    bn_splits=args.bn_splits,
    symmetric=args.symmetric,
).cuda()

checkpoint = torch.load("/home/lab-huang.haoran/moco_flowers/cache-2025-04-10-09-22-16-moco/model_last.pth", map_location="cuda")
model.load_state_dict(checkpoint['state_dict'])

# ------------------------------
# 调用 test 函数测试模型
# 注意：这里调用的是 model.encoder_q，因为测试时只需要提取 query 特征
epoch = 1  # 此处的 epoch 值仅用于调用 test 函数
accuracy, results = test(model.encoder_q, memory_loader, test_loader, epoch, args)
print("Test Accuracy: {:.2f}%".format(accuracy))
# Out:
# Feature extracting: 100%|██████████| 98/98 [00:05<00:00, 16.57it/s]
# Test Epoch: Acc@1: 77.28%:  15%|█▌        | 3/20 [00:00<00:04,  4.21it/s]
# 第1张图片：预测名称是“cat”，实际名称是“cat”
# 第2张图片：预测名称是“ship”，实际名称是“ship”
# 第3张图片：预测名称是“automobile”，实际名称是“ship”
# 第4张图片：预测名称是“airplane”，实际名称是“airplane”
# 第5张图片：预测名称是“frog”，实际名称是“frog”
# 第6张图片：预测名称是“frog”，实际名称是“frog”
# 第7张图片：预测名称是“automobile”，实际名称是“automobile”
# 第8张图片：预测名称是“bird”，实际名称是“frog”
# 第9张图片：预测名称是“cat”，实际名称是“cat”
# 第10张图片：预测名称是“automobile”，实际名称是“automobile”
# 第11张图片：预测名称是“airplane”，实际名称是“airplane”
# 第12张图片：预测名称是“truck”，实际名称是“truck”
# 第13张图片：预测名称是“dog”，实际名称是“dog”
# 第14张图片：预测名称是“horse”，实际名称是“horse”
# 第15张图片：预测名称是“truck”，实际名称是“truck”
# 第16张图片：预测名称是“ship”，实际名称是“ship”
# 第17张图片：预测名称是“dog”，实际名称是“dog”
# 第18张图片：预测名称是“horse”，实际名称是“horse”
# 第19张图片：预测名称是“ship”，实际名称是“ship”
# 第20张图片：预测名称是“frog”，实际名称是“frog”
# 第21张图片：预测名称是“horse”，实际名称是“horse”
# 第22张图片：预测名称是“airplane”，实际名称是“airplane”
# 第23张图片：预测名称是“deer”，实际名称是“deer”
# 第24张图片：预测名称是“truck”，实际名称是“truck”
# 第25张图片：预测名称是“deer”，实际名称是“dog”
# 第26张图片：预测名称是“bird”，实际名称是“bird”
# 第27张图片：预测名称是“deer”，实际名称是“deer”
# 第28张图片：预测名称是“airplane”，实际名称是“airplane”
# 第29张图片：预测名称是“truck”，实际名称是“truck”
# 第30张图片：预测名称是“frog”，实际名称是“frog”
# 第31张图片：预测名称是“frog”，实际名称是“frog”
# 第32张图片：预测名称是“dog”，实际名称是“dog”
# 第33张图片：预测名称是“deer”，实际名称是“deer”
# 第34张图片：预测名称是“dog”，实际名称是“dog”
# 第35张图片：预测名称是“truck”，实际名称是“truck”
# 第36张图片：预测名称是“bird”，实际名称是“bird”
# 第37张图片：预测名称是“deer”，实际名称是“deer”
# 第38张图片：预测名称是“automobile”，实际名称是“automobile”
# 第39张图片：预测名称是“truck”，实际名称是“truck”
# 第40张图片：预测名称是“dog”，实际名称是“dog”
# 第41张图片：预测名称是“deer”，实际名称是“deer”
# 第42张图片：预测名称是“frog”，实际名称是“frog”
# 第43张图片：预测名称是“horse”，实际名称是“dog”
# 第44张图片：预测名称是“frog”，实际名称是“frog”
# 第45张图片：预测名称是“airplane”，实际名称是“airplane”
# 第46张图片：预测名称是“truck”，实际名称是“truck”
# 第47张图片：预测名称是“cat”，实际名称是“cat”
# 第48张图片：预测名称是“truck”，实际名称是“truck”
# 第49张图片：预测名称是“horse”，实际名称是“horse”
# 第50张图片：预测名称是“frog”，实际名称是“frog”
# 第51张图片：预测名称是“truck”，实际名称是“truck”
# 第52张图片：预测名称是“ship”，实际名称是“ship”
# 第53张图片：预测名称是“dog”，实际名称是“airplane”
# 第54张图片：预测名称是“cat”，实际名称是“cat”
# 第55张图片：预测名称是“ship”，实际名称是“ship”
# 第56张图片：预测名称是“ship”，实际名称是“ship”
# 第57张图片：预测名称是“dog”，实际名称是“horse”
# 第58张图片：预测名称是“dog”，实际名称是“horse”
# 第59张图片：预测名称是“dog”，实际名称是“deer”
# 第60张图片：预测名称是“dog”，实际名称是“frog”
# 第61张图片：预测名称是“horse”，实际名称是“horse”
# 第62张图片：预测名称是“dog”，实际名称是“cat”
# 第63张图片：预测名称是“frog”，实际名称是“frog”
# 第64张图片：预测名称是“truck”，实际名称是“cat”
# 第65张图片：预测名称是“frog”，实际名称是“frog”
# 第66张图片：预测名称是“bird”，实际名称是“bird”
# 第67张图片：预测名称是“automobile”，实际名称是“automobile”
# 第68张图片：预测名称是“bird”，实际名称是“bird”
# 第69张图片：预测名称是“cat”，实际名称是“cat”
# 第70张图片：预测名称是“horse”，实际名称是“horse”
# 第71张图片：预测名称是“bird”，实际名称是“bird”
# 第72张图片：预测名称是“frog”，实际名称是“frog”
# 第73张图片：预测名称是“ship”，实际名称是“ship”
# 第74张图片：预测名称是“ship”，实际名称是“ship”
# 第75张图片：预测名称是“airplane”，实际名称是“airplane”
# 第76张图片：预测名称是“bird”，实际名称是“bird”
# 第77张图片：预测名称是“truck”，实际名称是“truck”
# 第78张图片：预测名称是“cat”，实际名称是“cat”
# 第79张图片：预测名称是“dog”，实际名称是“cat”
# 第80张图片：预测名称是“ship”，实际名称是“ship”
# 第81张图片：预测名称是“ship”，实际名称是“ship”
# 第82张图片：预测名称是“automobile”，实际名称是“automobile”
# 第83张图片：预测名称是“automobile”，实际名称是“automobile”
# 第84张图片：预测名称是“horse”，实际名称是“horse”
# 第85张图片：预测名称是“bird”，实际名称是“bird”
# 第86张图片：预测名称是“horse”，实际名称是“dog”
# 第87张图片：预测名称是“bird”，实际名称是“bird”
# 第88张图片：预测名称是“horse”，实际名称是“horse”
# 第89张图片：预测名称是“ship”，实际名称是“ship”
# 第90张图片：预测名称是“truck”，实际名称是“truck”
# 第91张图片：预测名称是“airplane”，实际名称是“airplane”
# 第92张图片：预测名称是“bird”，实际名称是“cat”
# 第93张图片：预测名称是“ship”，实际名称是“ship”
# 第94张图片：预测名称是“frog”，实际名称是“frog”
# 第95张图片：预测名称是“deer”，实际名称是“deer”
# 第96张图片：预测名称是“frog”，实际名称是“frog”
# 第97张图片：预测名称是“frog”，实际名称是“frog”
# 第98张图片：预测名称是“airplane”，实际名称是“airplane”
# 第99张图片：预测名称是“airplane”，实际名称是“airplane”
# 第100张图片：预测名称是“horse”，实际名称是“horse”
# 第101张图片：预测名称是“deer”，实际名称是“deer”
# 第102张图片：预测名称是“deer”，实际名称是“dog”
# 第103张图片：预测名称是“frog”，实际名称是“frog”
# 第104张图片：预测名称是“frog”，实际名称是“cat”
# 第105张图片：预测名称是“automobile”，实际名称是“automobile”
# 第106张图片：预测名称是“automobile”，实际名称是“automobile”
# 第107张图片：预测名称是“cat”，实际名称是“cat”
# 第108张图片：预测名称是“frog”，实际名称是“frog”
# 第109张图片：预测名称是“ship”，实际名称是“ship”
# 第110张图片：预测名称是“dog”，实际名称是“horse”
# 第111张图片：预测名称是“deer”，实际名称是“deer”
# 第112张图片：预测名称是“airplane”，实际名称是“airplane”
# 第113张图片：预测名称是“bird”，实际名称是“frog”
# 第114张图片：预测名称是“bird”，实际名称是“bird”
# 第115张图片：预测名称是“automobile”，实际名称是“automobile”
# 第116张图片：预测名称是“cat”，实际名称是“cat”
# 第117张图片：预测名称是“airplane”，实际名称是“airplane”
# 第118张图片：预测名称是“horse”，实际名称是“deer”
# 第119张图片：预测名称是“frog”，实际名称是“bird”
# 第120张图片：预测名称是“horse”，实际名称是“horse”
# 第121张图片：预测名称是“ship”，实际名称是“ship”
# 第122张图片：预测名称是“cat”，实际名称是“cat”
# 第123张图片：预测名称是“automobile”，实际名称是“automobile”
# 第124张图片：预测名称是“bird”，实际名称是“bird”
# 第125张图片：预测名称是“ship”，实际名称是“ship”
# 第126张图片：预测名称是“bird”，实际名称是“airplane”
# 第127张图片：预测名称是“ship”，实际名称是“ship”
# 第128张图片：预测名称是“cat”，实际名称是“cat”
# 第129张图片：预测名称是“cat”，实际名称是“dog”
# 第130张图片：预测名称是“bird”，实际名称是“bird”
# 第131张图片：预测名称是“deer”，实际名称是“deer”
# 第132张图片：预测名称是“automobile”，实际名称是“automobile”
# 第133张图片：预测名称是“ship”，实际名称是“ship”
# 第134张图片：预测名称是“truck”，实际名称是“truck”
# 第135张图片：预测名称是“automobile”，实际名称是“automobile”
# 第136张图片：预测名称是“bird”，实际名称是“bird”
# 第137张图片：预测名称是“truck”，实际名称是“truck”
# 第138张图片：预测名称是“horse”，实际名称是“horse”
# 第139张图片：预测名称是“deer”，实际名称是“bird”
# 第140张图片：预测名称是“ship”，实际名称是“truck”
# 第141张图片：预测名称是“frog”，实际名称是“frog”
# 第142张图片：预测名称是“dog”，实际名称是“dog”
# 第143张图片：预测名称是“frog”，实际名称是“frog”
# 第144张图片：预测名称是“cat”，实际名称是“cat”
# 第145张图片：预测名称是“ship”，实际名称是“ship”
# 第146张图片：预测名称是“dog”，实际名称是“horse”
# 第147张图片：预测名称是“frog”，实际名称是“frog”
# 第148张图片：预测名称是“dog”，实际名称是“bird”
# 第149张图片：预测名称是“dog”，实际名称是“dog”
# 第150张图片：预测名称是“bird”，实际名称是“bird”
# 第151张图片：预测名称是“airplane”，实际名称是“ship”
# 第152张图片：预测名称是“truck”，实际名称是“truck”
# 第153张图片：预测名称是“frog”，实际名称是“frog”
# 第154张图片：预测名称是“airplane”，实际名称是“airplane”
# 第155张图片：预测名称是“airplane”，实际名称是“airplane”
# 第156张图片：预测名称是“dog”，实际名称是“dog”
# 第157张图片：预测名称是“bird”，实际名称是“bird”
# 第158张图片：预测名称是“truck”，实际名称是“truck”
# 第159张图片：预测名称是“cat”，实际名称是“dog”
# 第160张图片：预测名称是“deer”，实际名称是“deer”
# 第161张图片：预测名称是“airplane”，实际名称是“bird”
# 第162张图片：预测名称是“automobile”，实际名称是“automobile”
# 第163张图片：预测名称是“dog”，实际名称是“frog”
# 第164张图片：预测名称是“frog”，实际名称是“frog”
# 第165张图片：预测名称是“airplane”，实际名称是“ship”
# 第166张图片：预测名称是“bird”，实际名称是“deer”
# 第167张图片：预测名称是“ship”，实际名称是“ship”
# 第168张图片：预测名称是“deer”，实际名称是“deer”
# 第169张图片：预测名称是“dog”，实际名称是“dog”
# 第170张图片：预测名称是“ship”，实际名称是“airplane”
# 第171张图片：预测名称是“truck”，实际名称是“truck”
# 第172张图片：预测名称是“truck”，实际名称是“truck”
# 第173张图片：预测名称是“truck”，实际名称是“truck”
# 第174张图片：预测名称是“ship”，实际名称是“ship”
# 第175张图片：预测名称是“truck”，实际名称是“truck”
# 第176张图片：预测名称是“truck”，实际名称是“truck”
# 第177张图片：预测名称是“cat”，实际名称是“cat”
# 第178张图片：预测名称是“horse”，实际名称是“horse”
# 第179张图片：预测名称是“dog”，实际名称是“dog”
# 第180张图片：预测名称是“airplane”，实际名称是“airplane”
# 第181张图片：预测名称是“airplane”，实际名称是“airplane”
# 第182张图片：预测名称是“dog”，实际名称是“dog”
# 第183张图片：预测名称是“bird”，实际名称是“bird”
# 第184张图片：预测名称是“bird”，实际名称是“bird”
# 第185张图片：预测名称是“cat”，实际名称是“cat”
# 第186张图片：预测名称是“ship”，实际名称是“ship”
# 第187张图片：预测名称是“frog”，实际名称是“frog”
# 第188张图片：预测名称是“cat”，实际名称是“cat”
# 第189张图片：预测名称是“cat”，实际名称是“deer”
# 第190张图片：预测名称是“airplane”，实际名称是“airplane”
# 第191张图片：预测名称是“dog”，实际名称是“dog”
# 第192张图片：预测名称是“ship”，实际名称是“ship”
# 第193张图片：预测名称是“airplane”，实际名称是“airplane”
# 第194张图片：预测名称是“automobile”，实际名称是“automobile”
# 第195张图片：预测名称是“frog”，实际名称是“horse”
# 第196张图片：预测名称是“bird”，实际名称是“bird”
# 第197张图片：预测名称是“ship”，实际名称是“ship”
# 第198张图片：预测名称是“ship”，实际名称是“ship”
# 第199张图片：预测名称是“horse”，实际名称是“horse”
# 第200张图片：预测名称是“ship”，实际名称是“ship”
# 第201张图片：预测名称是“cat”，实际名称是“dog”
# 第202张图片：预测名称是“airplane”，实际名称是“automobile”
# 第203张图片：预测名称是“ship”，实际名称是“ship”
# 第204张图片：预测名称是“horse”，实际名称是“horse”
# 第205张图片：预测名称是“automobile”，实际名称是“automobile”
# 第206张图片：预测名称是“cat”，实际名称是“cat”
# 第207张图片：预测名称是“airplane”，实际名称是“airplane”
# 第208张图片：预测名称是“dog”，实际名称是“dog”
# 第209张图片：预测名称是“horse”，实际名称是“horse”
# 第210张图片：预测名称是“truck”，实际名称是“truck”
# 第211张图片：预测名称是“bird”，实际名称是“horse”
# 第212张图片：预测名称是“ship”，实际名称是“deer”
# 第213张图片：预测名称是“dog”，实际名称是“dog”
# 第214张图片：预测名称是“truck”，实际名称是“truck”
# 第215张图片：预测名称是“ship”，实际名称是“ship”
# 第216张图片：预测名称是“airplane”，实际名称是“airplane”
# 第217张图片：预测名称是“horse”，实际名称是“horse”
# 第218张图片：预测名称是“truck”，实际名称是“truck”
# 第219张图片：预测名称是“ship”，实际名称是“ship”
# 第220张图片：预测名称是“horse”，实际名称是“bird”
# 第221张图片：预测名称是“horse”，实际名称是“horse”
# 第222张图片：预测名称是“cat”，实际名称是“frog”
# 第223张图片：预测名称是“truck”，实际名称是“truck”
# 第224张图片：预测名称是“deer”，实际名称是“deer”
# 第225张图片：预测名称是“dog”，实际名称是“cat”
# 第226张图片：预测名称是“truck”，实际名称是“truck”
# 第227张图片：预测名称是“deer”，实际名称是“frog”
# 第228张图片：预测名称是“deer”，实际名称是“deer”
# 第229张图片：预测名称是“dog”，实际名称是“horse”
# 第230张图片：预测名称是“frog”，实际名称是“frog”
# 第231张图片：预测名称是“dog”，实际名称是“dog”
# 第232张图片：预测名称是“automobile”，实际名称是“automobile”
# 第233张图片：预测名称是“dog”，实际名称是“dog”
# 第234张图片：预测名称是“ship”，实际名称是“ship”
# 第235张图片：预测名称是“ship”，实际名称是“ship”
# 第236张图片：预测名称是“airplane”，实际名称是“airplane”
# 第237张图片：预测名称是“deer”，实际名称是“deer”
# 第238张图片：预测名称是“truck”，实际名称是“airplane”
# 第239张图片：预测名称是“dog”，实际名称是“dog”
# 第240张图片：预测名称是“frog”，实际名称是“dog”
# 第241张图片：预测名称是“automobile”，实际名称是“automobile”
# 第242张图片：预测名称是“automobile”，实际名称是“automobile”
# 第243张图片：预测名称是“automobile”，实际名称是“ship”
# 第244张图片：预测名称是“truck”，实际名称是“truck”
# 第245张图片：预测名称是“airplane”，实际名称是“airplane”
# 第246张图片：预测名称是“frog”，实际名称是“cat”
# 第247张图片：预测名称是“automobile”，实际名称是“automobile”
# 第248张图片：预测名称是“truck”，实际名称是“truck”
# 第249张图片：预测名称是“bird”，实际名称是“bird”
# 第250张图片：预测名称是“bird”，实际名称是“bird”
# 第251张图片：预测名称是“dog”，实际名称是“dog”
# 第252张图片：预测名称是“cat”，实际名称是“cat”
# 第253张图片：预测名称是“truck”，实际名称是“truck”
# 第254张图片：预测名称是“truck”，实际名称是“truck”
# 第255张图片：预测名称是“deer”，实际名称是“deer”
# 第256张图片：预测名称是“airplane”，实际名称是“airplane”
# 第257张图片：预测名称是“frog”，实际名称是“cat”
# 第258张图片：预测名称是“airplane”，实际名称是“airplane”
# 第259张图片：预测名称是“airplane”，实际名称是“airplane”
# 第260张图片：预测名称是“truck”，实际名称是“truck”
# 第261张图片：预测名称是“ship”，实际名称是“ship”
# 第262张图片：预测名称是“automobile”，实际名称是“automobile”
# 第263张图片：预测名称是“cat”，实际名称是“dog”
# 第264张图片：预测名称是“frog”，实际名称是“horse”
# 第265张图片：预测名称是“airplane”，实际名称是“airplane”
# 第266张图片：预测名称是“ship”，实际名称是“ship”
# 第267张图片：预测名称是“bird”，实际名称是“bird”
# 第268张图片：预测名称是“deer”，实际名称是“deer”
# 第269张图片：预测名称是“horse”，实际名称是“horse”
# 第270张图片：预测名称是“bird”，实际名称是“airplane”
# 第271张图片：预测名称是“cat”，实际名称是“bird”
# 第272张图片：预测名称是“dog”，实际名称是“cat”
# 第273张图片：预测名称是“frog”，实际名称是“frog”
# 第274张图片：预测名称是“cat”，实际名称是“cat”
# 第275张图片：预测名称是“ship”，实际名称是“ship”
# 第276张图片：预测名称是“horse”，实际名称是“dog”
# 第277张图片：预测名称是“airplane”，实际名称是“airplane”
# 第278张图片：预测名称是“bird”，实际名称是“cat”
# 第279张图片：预测名称是“deer”，实际名称是“deer”
# 第280张图片：预测名称是“dog”，实际名称是“cat”
# 第281张图片：预测名称是“truck”，实际名称是“truck”
# 第282张图片：预测名称是“ship”，实际名称是“airplane”
# 第283张图片：预测名称是“frog”，实际名称是“frog”
# 第284张图片：预测名称是“automobile”，实际名称是“automobile”
# 第285张图片：预测名称是“truck”，实际名称是“airplane”
# 第286张图片：预测名称是“truck”，实际名称是“truck”
# 第287张图片：预测名称是“automobile”，实际名称是“automobile”
# 第288张图片：预测名称是“airplane”，实际名称是“airplane”
# 第289张图片：预测名称是“horse”，实际名称是“horse”
# 第290张图片：预测名称是“truck”，实际名称是“truck”
# 第291张图片：预测名称是“automobile”，实际名称是“automobile”
# 第292张图片：预测名称是“bird”，实际名称是“bird”
# 第293张图片：预测名称是“frog”，实际名称是“frog”
# 第294张图片：预测名称是“truck”，实际名称是“truck”
# 第295张图片：预测名称是“dog”，实际名称是“cat”
# 第296张图片：预测名称是“bird”，实际名称是“deer”
# 第297张图片：预测名称是“frog”，实际名称是“frog”
# 第298张图片：预测名称是“airplane”，实际名称是“airplane”
# 第299张图片：预测名称是“airplane”，实际名称是“airplane”
# 第300张图片：预测名称是“frog”，实际名称是“frog”
# 第301张图片：预测名称是“frog”，实际名称是“frog”
# 第302张图片：预测名称是“frog”，实际名称是“frog”
# 第303张图片：预测名称是“dog”，实际名称是“cat”
# 第304张图片：预测名称是“bird”，实际名称是“bird”
# 第305张图片：预测名称是“frog”，实际名称是“frog”
# 第306张图片：预测名称是“automobile”，实际名称是“automobile”
# 第307张图片：预测名称是“truck”，实际名称是“ship”
# 第308张图片：预测名称是“cat”，实际名称是“bird”
# 第309张图片：预测名称是“automobile”，实际名称是“automobile”
# 第310张图片：预测名称是“bird”，实际名称是“frog”
# 第311张图片：预测名称是“ship”，实际名称是“ship”
# 第312张图片：预测名称是“frog”，实际名称是“frog”
# 第313张图片：预测名称是“ship”，实际名称是“ship”
# 第314张图片：预测名称是“airplane”，实际名称是“airplane”
# 第315张图片：预测名称是“deer”，实际名称是“deer”
# 第316张图片：预测名称是“horse”，实际名称是“airplane”
# 第317张图片：预测名称是“horse”，实际名称是“horse”
# 第318张图片：预测名称是“deer”，实际名称是“horse”
# 第319张图片：预测名称是“dog”，实际名称是“dog”
# 第320张图片：预测名称是“dog”，实际名称是“dog”
# 第321张图片：预测名称是“cat”，实际名称是“cat”
# 第322张图片：预测名称是“dog”，实际名称是“dog”
# 第323张图片：预测名称是“frog”，实际名称是“bird”
# 第324张图片：预测名称是“cat”，实际名称是“cat”
# 第325张图片：预测名称是“horse”，实际名称是“deer”
# 第326张图片：预测名称是“automobile”，实际名称是“automobile”
# 第327张图片：预测名称是“horse”，实际名称是“horse”
# 第328张图片：预测名称是“dog”，实际名称是“dog”
# 第329张图片：预测名称是“deer”，实际名称是“deer”
# 第330张图片：预测名称是“frog”，实际名称是“frog”
# 第331张图片：预测名称是“automobile”，实际名称是“automobile”
# 第332张图片：预测名称是“automobile”，实际名称是“truck”
# 第333张图片：预测名称是“cat”，实际名称是“cat”
# 第334张图片：预测名称是“frog”，实际名称是“frog”
# 第335张图片：预测名称是“frog”，实际名称是“frog”
# 第336张图片：预测名称是“truck”，实际名称是“truck”
# 第337张图片：预测名称是“cat”，实际名称是“cat”
# 第338张图片：预测名称是“ship”，实际名称是“ship”
# 第339张图片：预测名称是“airplane”，实际名称是“airplane”
# 第340张图片：预测名称是“horse”，实际名称是“horse”
# 第341张图片：预测名称是“frog”，实际名称是“bird”
# 第342张图片：预测名称是“frog”，实际名称是“frog”
# 第343张图片：预测名称是“airplane”，实际名称是“bird”
# 第344张图片：预测名称是“dog”，实际名称是“dog”
# 第345张图片：预测名称是“ship”，实际名称是“ship”
# 第346张图片：预测名称是“dog”，实际名称是“dog”
# 第347张图片：预测名称是“deer”，实际名称是“deer”
# 第348张图片：预测名称是“frog”，实际名称是“frog”
# 第349张图片：预测名称是“ship”，实际名称是“ship”
# 第350张图片：预测名称是“truck”，实际名称是“truck”
# 第351张图片：预测名称是“truck”，实际名称是“truck”
# 第352张图片：预测名称是“automobile”，实际名称是“automobile”
# 第353张图片：预测名称是“ship”，实际名称是“airplane”
# 第354张图片：预测名称是“bird”，实际名称是“bird”
# 第355张图片：预测名称是“bird”，实际名称是“bird”
# 第356张图片：预测名称是“deer”，实际名称是“horse”
# 第357张图片：预测名称是“deer”，实际名称是“cat”
# 第358张图片：预测名称是“bird”，实际名称是“bird”
# 第359张图片：预测名称是“ship”，实际名称是“ship”
# 第360张图片：预测名称是“airplane”，实际名称是“airplane”
# 第361张图片：预测名称是“truck”，实际名称是“truck”
# 第362张图片：预测名称是“dog”，实际名称是“dog”
# 第363张图片：预测名称是“ship”，实际名称是“ship”
# 第364张图片：预测名称是“automobile”，实际名称是“automobile”
# 第365张图片：预测名称是“truck”，实际名称是“truck”
# 第366张图片：预测名称是“deer”，实际名称是“deer”
# 第367张图片：预测名称是“automobile”，实际名称是“automobile”
# 第368张图片：预测名称是“dog”，实际名称是“cat”
# 第369张图片：预测名称是“deer”，实际名称是“ship”
# 第370张图片：预测名称是“automobile”，实际名称是“automobile”
# 第371张图片：预测名称是“deer”，实际名称是“deer”
# 第372张图片：预测名称是“horse”，实际名称是“horse”
# 第373张图片：预测名称是“truck”，实际名称是“truck”
# 第374张图片：预测名称是“deer”，实际名称是“deer”
# 第375张图片：预测名称是“bird”，实际名称是“bird”
# 第376张图片：预测名称是“horse”，实际名称是“horse”
# 第377张图片：预测名称是“truck”，实际名称是“airplane”
# 第378张图片：预测名称是“deer”，实际名称是“horse”
# 第379张图片：预测名称是“bird”，实际名称是“airplane”
# 第380张图片：预测名称是“frog”，实际名称是“frog”
# 第381张图片：预测名称是“frog”，实际名称是“frog”
# 第382张图片：预测名称是“truck”，实际名称是“truck”
# 第383张图片：预测名称是“airplane”，实际名称是“airplane”
# 第384张图片：预测名称是“automobile”，实际名称是“truck”
# 第385张图片：预测名称是“dog”，实际名称是“bird”
# 第386张图片：预测名称是“airplane”，实际名称是“ship”
# 第387张图片：预测名称是“horse”，实际名称是“horse”
# 第388张图片：预测名称是“dog”，实际名称是“bird”
# 第389张图片：预测名称是“bird”，实际名称是“bird”
# 第390张图片：预测名称是“dog”，实际名称是“dog”
# 第391张图片：预测名称是“automobile”，实际名称是“automobile”
# 第392张图片：预测名称是“airplane”，实际名称是“bird”
# 第393张图片：预测名称是“frog”，实际名称是“frog”
# 第394张图片：预测名称是“bird”，实际名称是“bird”
# 第395张图片：预测名称是“automobile”，实际名称是“truck”
# 第396张图片：预测名称是“frog”，实际名称是“frog”
# 第397张图片：预测名称是“bird”，实际名称是“bird”
# 第398张图片：预测名称是“cat”，实际名称是“cat”
# 第399张图片：预测名称是“airplane”，实际名称是“airplane”
# 第400张图片：预测名称是“cat”，实际名称是“cat”
# 第401张图片：预测名称是“truck”，实际名称是“truck”
# 第402张图片：预测名称是“automobile”，实际名称是“ship”
# 第403张图片：预测名称是“horse”，实际名称是“horse”
# 第404张图片：预测名称是“ship”，实际名称是“ship”
# 第405张图片：预测名称是“ship”，实际名称是“ship”
# 第406张图片：预测名称是“deer”，实际名称是“deer”
# 第407张图片：预测名称是“airplane”，实际名称是“airplane”
# 第408张图片：预测名称是“automobile”，实际名称是“automobile”
# 第409张图片：预测名称是“ship”，实际名称是“ship”
# 第410张图片：预测名称是“bird”，实际名称是“bird”
# 第411张图片：预测名称是“horse”，实际名称是“horse”
# 第412张图片：预测名称是“truck”，实际名称是“truck”
# 第413张图片：预测名称是“dog”，实际名称是“cat”
# 第414张图片：预测名称是“frog”，实际名称是“frog”
# 第415张图片：预测名称是“automobile”，实际名称是“automobile”
# 第416张图片：预测名称是“truck”，实际名称是“truck”
# 第417张图片：预测名称是“airplane”，实际名称是“airplane”
# 第418张图片：预测名称是“horse”，实际名称是“horse”
# 第419张图片：预测名称是“cat”，实际名称是“cat”
# 第420张图片：预测名称是“dog”，实际名称是“horse”
# 第421张图片：预测名称是“deer”，实际名称是“deer”
# 第422张图片：预测名称是“dog”，实际名称是“dog”
# 第423张图片：预测名称是“ship”，实际名称是“airplane”
# 第424张图片：预测名称是“airplane”，实际名称是“airplane”
# 第425张图片：预测名称是“bird”，实际名称是“bird”
# 第426张图片：预测名称是“truck”，实际名称是“truck”
# 第427张图片：预测名称是“cat”，实际名称是“cat”
# 第428张图片：预测名称是“truck”，实际名称是“deer”
# 第429张图片：预测名称是“frog”，实际名称是“airplane”
# 第430张图片：预测名称是“frog”，实际名称是“frog”
# 第431张图片：预测名称是“bird”，实际名称是“bird”
# 第432张图片：预测名称是“dog”，实际名称是“dog”
# 第433张图片：预测名称是“cat”，实际名称是“cat”
# 第434张图片：预测名称是“cat”，实际名称是“horse”
# 第435张图片：预测名称是“truck”，实际名称是“cat”
# 第436张图片：预测名称是“horse”，实际名称是“horse”
# 第437张图片：预测名称是“frog”，实际名称是“bird”
# 第438张图片：预测名称是“dog”，实际名称是“dog”
# 第439张图片：预测名称是“dog”，实际名称是“cat”
# 第440张图片：预测名称是“automobile”，实际名称是“automobile”
# 第441张图片：预测名称是“automobile”，实际名称是“automobile”
# 第442张图片：预测名称是“deer”，实际名称是“deer”
# 第443张图片：预测名称是“truck”，实际名称是“truck”
# 第444张图片：预测名称是“truck”，实际名称是“truck”
# 第445张图片：预测名称是“dog”，实际名称是“dog”
# 第446张图片：预测名称是“deer”，实际名称是“horse”
# 第447张图片：预测名称是“dog”，实际名称是“dog”
# 第448张图片：预测名称是“airplane”，实际名称是“airplane”
# 第449张图片：预测名称是“bird”，实际名称是“bird”
# 第450张图片：预测名称是“airplane”，实际名称是“bird”
# 第451张图片：预测名称是“bird”，实际名称是“bird”
# 第452张图片：预测名称是“truck”，实际名称是“truck”
# 第453张图片：预测名称是“horse”，实际名称是“horse”
# 第454张图片：预测名称是“cat”，实际名称是“cat”
# 第455张图片：预测名称是“truck”，实际名称是“truck”
# 第456张图片：预测名称是“bird”，实际名称是“deer”
# 第457张图片：预测名称是“deer”，实际名称是“cat”
# 第458张图片：预测名称是“dog”，实际名称是“dog”
# 第459张图片：预测名称是“frog”，实际名称是“deer”
# 第460张图片：预测名称是“bird”，实际名称是“frog”
# 第461张图片：预测名称是“dog”，实际名称是“dog”
# 第462张图片：预测名称是“frog”，实际名称是“frog”
# 第463张图片：预测名称是“automobile”，实际名称是“automobile”
# 第464张图片：预测名称是“deer”，实际名称是“deer”
# 第465张图片：预测名称是“cat”，实际名称是“cat”
# 第466张图片：预测名称是“deer”，实际名称是“deer”
# 第467张图片：预测名称是“deer”，实际名称是“deer”
# 第468张图片：预测名称是“frog”，实际名称是“cat”
# 第469张图片：预测名称是“bird”，实际名称是“horse”
# 第470张图片：预测名称是“ship”，实际名称是“ship”
# 第471张图片：预测名称是“cat”，实际名称是“cat”
# 第472张图片：预测名称是“horse”，实际名称是“horse”
# 第473张图片：预测名称是“ship”，实际名称是“ship”
# 第474张图片：预测名称是“airplane”，实际名称是“airplane”
# 第475张图片：预测名称是“horse”，实际名称是“dog”
# 第476张图片：预测名称是“horse”，实际名称是“horse”
# 第477张图片：预测名称是“frog”，实际名称是“frog”
# 第478张图片：预测名称是“truck”，实际名称是“airplane”
# 第479张图片：预测名称是“dog”，实际名称是“dog”
# 第480张图片：预测名称是“deer”，实际名称是“deer”
# 第481张图片：预测名称是“ship”，实际名称是“ship”
# 第482张图片：预测名称是“frog”，实际名称是“frog”
# 第483张图片：预测名称是“ship”，实际名称是“ship”
# 第484张图片：预测名称是“horse”，实际名称是“dog”
# 第485张图片：预测名称是“dog”，实际名称是“dog”
# 第486张图片：预测名称是“ship”，实际名称是“truck”
# 第487张图片：预测名称是“truck”，实际名称是“truck”
# 第488张图片：预测名称是“truck”，实际名称是“truck”
# 第489张图片：预测名称是“deer”，实际名称是“dog”
# 第490张图片：预测名称是“airplane”，实际名称是“airplane”
# 第491张图片：预测名称是“automobile”，实际名称是“automobile”
# 第492张图片：预测名称是“airplane”，实际名称是“airplane”
# 第493张图片：预测名称是“ship”，实际名称是“ship”
# 第494张图片：预测名称是“automobile”，实际名称是“automobile”
# 第495张图片：预测名称是“automobile”，实际名称是“automobile”
# 第496张图片：预测名称是“ship”，实际名称是“ship”
# 第497张图片：预测名称是“ship”，实际名称是“airplane”
# 第498张图片：预测名称是“bird”，实际名称是“bird”
# 第499张图片：预测名称是“bird”，实际名称是“bird”
# 第500张图片：预测名称是“airplane”，实际名称是“airplane”
# 第501张图片：预测名称是“deer”，实际名称是“deer”
# 第502张图片：预测名称是“frog”，实际名称是“frog”
# 第503张图片：预测名称是“dog”，实际名称是“dog”
# 第504张图片：预测名称是“dog”，实际名称是“deer”
# 第505张图片：预测名称是“truck”，实际名称是“truck”
# 第506张图片：预测名称是“horse”，实际名称是“deer”
# 第507张图片：预测名称是“horse”，实际名称是“horse”
# 第508张图片：预测名称是“truck”，实际名称是“truck”
# 第509张图片：预测名称是“bird”，实际名称是“truck”
# 第510张图片：预测名称是“deer”，实际名称是“deer”
# 第511张图片：预测名称是“dog”，实际名称是“dog”
# 第512张图片：预测名称是“frog”，实际名称是“frog”
# 第513张图片：预测名称是“frog”，实际名称是“frog”
# 第514张图片：预测名称是“automobile”，实际名称是“automobile”
# 第515张图片：预测名称是“dog”，实际名称是“dog”
# 第516张图片：预测名称是“cat”，实际名称是“cat”
# 第517张图片：预测名称是“ship”，实际名称是“ship”
# 第518张图片：预测名称是“truck”，实际名称是“truck”
# 第519张图片：预测名称是“horse”，实际名称是“dog”
# 第520张图片：预测名称是“ship”，实际名称是“ship”
# 第521张图片：预测名称是“dog”，实际名称是“dog”
# 第522张图片：预测名称是“horse”，实际名称是“horse”
# 第523张图片：预测名称是“automobile”，实际名称是“airplane”
# 第524张图片：预测名称是“horse”，实际名称是“horse”
# 第525张图片：预测名称是“airplane”，实际名称是“airplane”
# 第526张图片：预测名称是“dog”，实际名称是“dog”
# 第527张图片：预测名称是“truck”，实际名称是“airplane”
# 第528张图片：预测名称是“airplane”，实际名称是“airplane”
# 第529张图片：预测名称是“deer”，实际名称是“deer”
# 第530张图片：预测名称是“frog”，实际名称是“frog”
# 第531张图片：预测名称是“truck”，实际名称是“truck”
# 第532张图片：预测名称是“airplane”，实际名称是“airplane”
# 第533张图片：预测名称是“truck”，实际名称是“truck”
# 第534张图片：预测名称是“dog”，实际名称是“dog”
# 第535张图片：预测名称是“frog”，实际名称是“frog”
# 第536张图片：预测名称是“frog”，实际名称是“frog”
# 第537张图片：预测名称是“frog”，实际名称是“frog”
# 第538张图片：预测名称是“bird”，实际名称是“bird”
# 第539张图片：预测名称是“truck”，实际名称是“truck”
# 第540张图片：预测名称是“airplane”，实际名称是“airplane”
# 第541张图片：预测名称是“automobile”，实际名称是“automobile”
# 第542张图片：预测名称是“horse”，实际名称是“horse”
# 第543张图片：预测名称是“frog”，实际名称是“frog”
# 第544张图片：预测名称是“horse”，实际名称是“horse”
# 第545张图片：预测名称是“dog”，实际名称是“dog”
# 第546张图片：预测名称是“truck”，实际名称是“truck”
# 第547张图片：预测名称是“automobile”，实际名称是“automobile”
# 第548张图片：预测名称是“frog”，实际名称是“frog”
# 第549张图片：预测名称是“bird”，实际名称是“bird”
# 第550张图片：预测名称是“dog”，实际名称是“dog”
# 第551张图片：预测名称是“bird”，实际名称是“dog”
# 第552张图片：预测名称是“cat”，实际名称是“dog”
# 第553张图片：预测名称是“ship”，实际名称是“ship”
# 第554张图片：预测名称是“dog”，实际名称是“dog”
# 第555张图片：预测名称是“truck”，实际名称是“truck”
# 第556张图片：预测名称是“deer”，实际名称是“deer”
# 第557张图片：预测名称是“cat”，实际名称是“frog”
# 第558张图片：预测名称是“deer”，实际名称是“deer”
# 第559张图片：预测名称是“dog”，实际名称是“cat”
# 第560张图片：预测名称是“bird”，实际名称是“bird”
# 第561张图片：预测名称是“airplane”，实际名称是“airplane”
# 第562张图片：预测名称是“horse”，实际名称是“horse”
# 第563张图片：预测名称是“frog”，实际名称是“frog”
# 第564张图片：预测名称是“deer”，实际名称是“bird”
# 第565张图片：预测名称是“deer”，实际名称是“bird”
# 第566张图片：预测名称是“dog”，实际名称是“cat”
# 第567张图片：预测名称是“truck”，实际名称是“truck”
# 第568张图片：预测名称是“horse”，实际名称是“horse”
# 第569张图片：预测名称是“truck”，实际名称是“truck”
# 第570张图片：预测名称是“frog”，实际名称是“bird”
# 第571张图片：预测名称是“frog”，实际名称是“frog”
# 第572张图片：预测名称是“horse”，实际名称是“horse”
# 第573张图片：预测名称是“automobile”，实际名称是“automobile”
# 第574张图片：预测名称是“cat”，实际名称是“cat”
# 第575张图片：预测名称是“frog”，实际名称是“frog”
# 第576张图片：预测名称是“frog”，实际名称是“frog”
# 第577张图片：预测名称是“ship”，实际名称是“ship”
# 第578张图片：预测名称是“truck”，实际名称是“truck”
# 第579张图片：预测名称是“horse”，实际名称是“horse”
# 第580张图片：预测名称是“dog”，实际名称是“dog”
# 第581张图片：预测名称是“deer”，实际名称是“deer”
# 第582张图片：预测名称是“ship”，实际名称是“airplane”
# 第583张图片：预测名称是“ship”，实际名称是“ship”
# 第584张图片：预测名称是“deer”，实际名称是“deer”
# 第585张图片：预测名称是“airplane”，实际名称是“airplane”
# 第586张图片：预测名称是“truck”，实际名称是“truck”
# 第587张图片：预测名称是“cat”，实际名称是“cat”
# 第588张图片：预测名称是“deer”，实际名称是“deer”
# 第589张图片：预测名称是“ship”，实际名称是“ship”
# 第590张图片：预测名称是“truck”，实际名称是“truck”
# 第591张图片：预测名称是“frog”，实际名称是“frog”
# 第592张图片：预测名称是“truck”，实际名称是“truck”
# 第593张图片：预测名称是“bird”，实际名称是“bird”
# 第594张图片：预测名称是“frog”，实际名称是“frog”
# 第595张图片：预测名称是“automobile”，实际名称是“automobile”
# 第596张图片：预测名称是“horse”，实际名称是“deer”
# 第597张图片：预测名称是“horse”，实际名称是“horse”
# 第598张图片：预测名称是“dog”，实际名称是“cat”
# 第599张图片：预测名称是“bird”，实际名称是“dog”
# 第600张图片：预测名称是“cat”，实际名称是“cat”
# 第601张图片：预测名称是“truck”，实际名称是“ship”
# 第602张图片：预测名称是“dog”，实际名称是“dog”
# 第603张图片：预测名称是“airplane”，实际名称是“airplane”
# 第604张图片：预测名称是“bird”，实际名称是“bird”
# 第605张图片：预测名称是“automobile”，实际名称是“automobile”
# 第606张图片：预测名称是“frog”，实际名称是“frog”
# 第607张图片：预测名称是“deer”，实际名称是“deer”
# 第608张图片：预测名称是“dog”，实际名称是“cat”
# 第609张图片：预测名称是“cat”，实际名称是“cat”
# 第610张图片：预测名称是“truck”，实际名称是“truck”
# 第611张图片：预测名称是“frog”，实际名称是“frog”
# 第612张图片：预测名称是“automobile”，实际名称是“truck”
# 第613张图片：预测名称是“ship”，实际名称是“ship”
# 第614张图片：预测名称是“ship”，实际名称是“ship”
# 第615张图片：预测名称是“dog”，实际名称是“dog”
# 第616张图片：预测名称是“truck”，实际名称是“ship”
# 第617张图片：预测名称是“frog”，实际名称是“frog”
# 第618张图片：预测名称是“deer”，实际名称是“frog”
# 第619张图片：预测名称是“cat”，实际名称是“bird”
# 第620张图片：预测名称是“automobile”，实际名称是“automobile”
# 第621张图片：预测名称是“bird”，实际名称是“horse”
# 第622张图片：预测名称是“horse”，实际名称是“horse”
# 第623张图片：预测名称是“automobile”，实际名称是“automobile”
# 第624张图片：预测名称是“bird”，实际名称是“bird”
# 第625张图片：预测名称是“horse”，实际名称是“horse”
# 第626张图片：预测名称是“truck”，实际名称是“truck”
# 第627张图片：预测名称是“truck”，实际名称是“truck”
# 第628张图片：预测名称是“deer”，实际名称是“deer”
# 第629张图片：预测名称是“deer”，实际名称是“deer”
# 第630张图片：预测名称是“automobile”，实际名称是“automobile”
# 第631张图片：预测名称是“deer”，实际名称是“bird”
# 第632张图片：预测名称是“bird”，实际名称是“dog”
# 第633张图片：预测名称是“frog”，实际名称是“frog”
# 第634张图片：预测名称是“ship”，实际名称是“ship”
# 第635张图片：预测名称是“horse”，实际名称是“horse”
# 第636张图片：预测名称是“frog”，实际名称是“frog”
# 第637张图片：预测名称是“ship”，实际名称是“ship”
# 第638张图片：预测名称是“bird”，实际名称是“cat”
# 第639张图片：预测名称是“ship”，实际名称是“airplane”
# 第640张图片：预测名称是“dog”，实际名称是“dog”
# 第641张图片：预测名称是“dog”，实际名称是“dog”
# 第642张图片：预测名称是“frog”，实际名称是“cat”
# 第643张图片：预测名称是“airplane”，实际名称是“airplane”
# 第644张图片：预测名称是“horse”，实际名称是“horse”
# 第645张图片：预测名称是“truck”，实际名称是“truck”
# 第646张图片：预测名称是“automobile”，实际名称是“automobile”
# 第647张图片：预测名称是“cat”，实际名称是“cat”
# 第648张图片：预测名称是“deer”，实际名称是“deer”
# 第649张图片：预测名称是“deer”，实际名称是“deer”
# 第650张图片：预测名称是“dog”，实际名称是“dog”
# 第651张图片：预测名称是“cat”，实际名称是“cat”
# 第652张图片：预测名称是“frog”，实际名称是“truck”
# 第653张图片：预测名称是“cat”，实际名称是“dog”
# 第654张图片：预测名称是“frog”，实际名称是“frog”
# 第655张图片：预测名称是“truck”，实际名称是“truck”
# 第656张图片：预测名称是“airplane”，实际名称是“bird”
# 第657张图片：预测名称是“automobile”，实际名称是“automobile”
# 第658张图片：预测名称是“automobile”，实际名称是“automobile”
# 第659张图片：预测名称是“deer”，实际名称是“deer”
# 第660张图片：预测名称是“automobile”，实际名称是“automobile”
# 第661张图片：预测名称是“truck”，实际名称是“truck”
# 第662张图片：预测名称是“deer”，实际名称是“deer”
# 第663张图片：预测名称是“horse”，实际名称是“horse”
# 第664张图片：预测名称是“frog”，实际名称是“frog”
# 第665张图片：预测名称是“cat”，实际名称是“cat”
# 第666张图片：预测名称是“airplane”，实际名称是“ship”
# 第667张图片：预测名称是“truck”，实际名称是“truck”
# 第668张图片：预测名称是“airplane”，实际名称是“airplane”
# 第669张图片：预测名称是“automobile”，实际名称是“automobile”
# 第670张图片：预测名称是“cat”，实际名称是“cat”
# 第671张图片：预测名称是“frog”，实际名称是“frog”
# 第672张图片：预测名称是“dog”，实际名称是“cat”
# 第673张图片：预测名称是“deer”，实际名称是“frog”
# 第674张图片：预测名称是“cat”，实际名称是“cat”
# 第675张图片：预测名称是“bird”，实际名称是“bird”
# 第676张图片：预测名称是“ship”，实际名称是“airplane”
# 第677张图片：预测名称是“cat”，实际名称是“cat”
# 第678张图片：预测名称是“automobile”，实际名称是“automobile”
# 第679张图片：预测名称是“airplane”，实际名称是“airplane”
# 第680张图片：预测名称是“dog”，实际名称是“dog”
# 第681张图片：预测名称是“truck”，实际名称是“truck”
# 第682张图片：预测名称是“frog”，实际名称是“frog”
# 第683张图片：预测名称是“horse”，实际名称是“deer”
# 第684张图片：预测名称是“automobile”，实际名称是“ship”
# 第685张图片：预测名称是“truck”，实际名称是“truck”
# 第686张图片：预测名称是“bird”，实际名称是“frog”
# 第687张图片：预测名称是“truck”，实际名称是“truck”
# 第688张图片：预测名称是“frog”，实际名称是“frog”
# 第689张图片：预测名称是“bird”，实际名称是“cat”
# 第690张图片：预测名称是“frog”，实际名称是“airplane”
# 第691张图片：预测名称是“deer”，实际名称是“cat”
# 第692张图片：预测名称是“bird”，实际名称是“bird”
# 第693张图片：预测名称是“airplane”，实际名称是“bird”
# 第694张图片：预测名称是“horse”，实际名称是“horse”
# 第695张图片：预测名称是“ship”，实际名称是“ship”
# 第696张图片：预测名称是“cat”，实际名称是“cat”
# 第697张图片：预测名称是“ship”，实际名称是“ship”
# 第698张图片：预测名称是“airplane”，实际名称是“bird”
# 第699张图片：预测名称是“horse”，实际名称是“horse”
# 第700张图片：预测名称是“dog”，实际名称是“dog”
# 第701张图片：预测名称是“horse”，实际名称是“horse”
# 第702张图片：预测名称是“bird”，实际名称是“bird”
# 第703张图片：预测名称是“deer”，实际名称是“deer”
# 第704张图片：预测名称是“ship”，实际名称是“ship”
# 第705张图片：预测名称是“horse”，实际名称是“horse”
# 第706张图片：预测名称是“deer”，实际名称是“deer”
# 第707张图片：预测名称是“bird”，实际名称是“bird”
# 第708张图片：预测名称是“truck”，实际名称是“truck”
# 第709张图片：预测名称是“ship”，实际名称是“ship”
# 第710张图片：预测名称是“ship”，实际名称是“ship”
# 第711张图片：预测名称是“bird”，实际名称是“frog”
# 第712张图片：预测名称是“ship”，实际名称是“ship”
# 第713张图片：预测名称是“ship”，实际名称是“ship”
# 第714张图片：预测名称是“horse”，实际名称是“horse”
# 第715张图片：预测名称是“deer”，实际名称是“deer”
# 第716张图片：预测名称是“cat”，实际名称是“cat”
# 第717张图片：预测名称是“cat”，实际名称是“cat”
# 第718张图片：预测名称是“cat”，实际名称是“ship”
# 第719张图片：预测名称是“bird”，实际名称是“deer”
# 第720张图片：预测名称是“truck”，实际名称是“truck”
# 第721张图片：预测名称是“deer”，实际名称是“deer”
# 第722张图片：预测名称是“ship”，实际名称是“ship”
# 第723张图片：预测名称是“ship”，实际名称是“ship”
# 第724张图片：预测名称是“automobile”，实际名称是“automobile”
# 第725张图片：预测名称是“ship”，实际名称是“ship”
# 第726张图片：预测名称是“ship”，实际名称是“bird”
# 第727张图片：预测名称是“automobile”，实际名称是“automobile”
# 第728张图片：预测名称是“cat”，实际名称是“cat”
# 第729张图片：预测名称是“frog”，实际名称是“frog”
# 第730张图片：预测名称是“dog”，实际名称是“dog”
# 第731张图片：预测名称是“deer”，实际名称是“deer”
# 第732张图片：预测名称是“airplane”，实际名称是“bird”
# 第733张图片：预测名称是“horse”，实际名称是“horse”
# 第734张图片：预测名称是“truck”，实际名称是“truck”
# 第735张图片：预测名称是“automobile”，实际名称是“truck”
# 第736张图片：预测名称是“frog”，实际名称是“deer”
# 第737张图片：预测名称是“automobile”，实际名称是“automobile”
# 第738张图片：预测名称是“deer”，实际名称是“deer”
# 第739张图片：预测名称是“automobile”，实际名称是“automobile”
# 第740张图片：预测名称是“dog”，实际名称是“cat”
# 第741张图片：预测名称是“dog”，实际名称是“bird”
# 第742张图片：预测名称是“horse”，实际名称是“horse”
# 第743张图片：预测名称是“airplane”，实际名称是“airplane”
# 第744张图片：预测名称是“horse”，实际名称是“horse”
# 第745张图片：预测名称是“bird”，实际名称是“truck”
# 第746张图片：预测名称是“horse”，实际名称是“horse”
# 第747张图片：预测名称是“deer”，实际名称是“frog”
# 第748张图片：预测名称是“frog”，实际名称是“frog”
# 第749张图片：预测名称是“bird”，实际名称是“bird”
# 第750张图片：预测名称是“cat”，实际名称是“dog”
# 第751张图片：预测名称是“truck”，实际名称是“truck”
# 第752张图片：预测名称是“airplane”，实际名称是“bird”
# 第753张图片：预测名称是“truck”，实际名称是“truck”
# 第754张图片：预测名称是“automobile”，实际名称是“automobile”
# 第755张图片：预测名称是“bird”，实际名称是“bird”
# 第756张图片：预测名称是“bird”，实际名称是“bird”
# 第757张图片：预测名称是“frog”，实际名称是“frog”
# 第758张图片：预测名称是“ship”，实际名称是“ship”
# 第759张图片：预测名称是“bird”，实际名称是“bird”
# 第760张图片：预测名称是“automobile”，实际名称是“automobile”
# 第761张图片：预测名称是“horse”，实际名称是“cat”
# 第762张图片：预测名称是“frog”，实际名称是“frog”
# 第763张图片：预测名称是“frog”，实际名称是“frog”
# 第764张图片：预测名称是“airplane”，实际名称是“airplane”
# 第765张图片：预测名称是“automobile”，实际名称是“automobile”
# 第766张图片：预测名称是“bird”，实际名称是“bird”
# 第767张图片：预测名称是“horse”，实际名称是“horse”
# 第768张图片：预测名称是“truck”，实际名称是“airplane”
# 第769张图片：预测名称是“dog”，实际名称是“dog”
# 第770张图片：预测名称是“deer”，实际名称是“deer”
# 第771张图片：预测名称是“airplane”，实际名称是“frog”
# 第772张图片：预测名称是“ship”，实际名称是“automobile”
# 第773张图片：预测名称是“frog”，实际名称是“frog”
# 第774张图片：预测名称是“frog”，实际名称是“deer”
# 第775张图片：预测名称是“airplane”，实际名称是“airplane”
# 第776张图片：预测名称是“deer”，实际名称是“bird”
# 第777张图片：预测名称是“bird”，实际名称是“bird”
# 第778张图片：预测名称是“frog”，实际名称是“frog”
# 第779张图片：预测名称是“airplane”，实际名称是“airplane”
# 第780张图片：预测名称是“dog”，实际名称是“dog”
# 第781张图片：预测名称是“truck”，实际名称是“truck”
# 第782张图片：预测名称是“automobile”，实际名称是“automobile”
# 第783张图片：预测名称是“horse”，实际名称是“horse”
# 第784张图片：预测名称是“frog”，实际名称是“frog”
# 第785张图片：预测名称是“deer”，实际名称是“horse”
# 第786张图片：预测名称是“ship”，实际名称是“airplane”
# 第787张图片：预测名称是“cat”，实际名称是“cat”
# 第788张图片：预测名称是“ship”，实际名称是“truck”
# 第789张图片：预测名称是“frog”，实际名称是“frog”
# 第790张图片：预测名称是“ship”，实际名称是“ship”
# 第791张图片：预测名称是“horse”，实际名称是“cat”
# 第792张图片：预测名称是“airplane”，实际名称是“airplane”
# 第793张图片：预测名称是“horse”，实际名称是“cat”
# 第794张图片：预测名称是“horse”，实际名称是“deer”
# 第795张图片：预测名称是“horse”，实际名称是“horse”
# 第796张图片：预测名称是“horse”，实际名称是“horse”
# 第797张图片：预测名称是“automobile”，实际名称是“automobile”
# 第798张图片：预测名称是“deer”，实际名称是“deer”
# 第799张图片：预测名称是“deer”，实际名称是“horse”
# 第800张图片：预测名称是“frog”，实际名称是“bird”
# 第801张图片：预测名称是“horse”，实际名称是“horse”
# 第802张图片：预测名称是“automobile”，实际名称是“automobile”
# 第803张图片：预测名称是“bird”，实际名称是“deer”
# 第804张图片：预测名称是“horse”，实际名称是“horse”
# 第805张图片：预测名称是“deer”，实际名称是“deer”
# 第806张图片：预测名称是“deer”，实际名称是“deer”
# 第807张图片：预测名称是“ship”，实际名称是“ship”
# 第808张图片：预测名称是“deer”，实际名称是“deer”
# 第809张图片：预测名称是“horse”，实际名称是“horse”
# 第810张图片：预测名称是“truck”，实际名称是“horse”
# 第811张图片：预测名称是“cat”，实际名称是“dog”
# 第812张图片：预测名称是“dog”，实际名称是“cat”
# 第813张图片：预测名称是“horse”，实际名称是“horse”
# 第814张图片：预测名称是“bird”，实际名称是“bird”
# 第815张图片：预测名称是“airplane”，实际名称是“airplane”
# 第816张图片：预测名称是“ship”，实际名称是“ship”
# 第817张图片：预测名称是“truck”，实际名称是“truck”
# 第818张图片：预测名称是“dog”，实际名称是“dog”
# 第819张图片：预测名称是“automobile”，实际名称是“ship”
# 第820张图片：预测名称是“cat”，实际名称是“cat”
# 第821张图片：预测名称是“frog”，实际名称是“frog”
# 第822张图片：预测名称是“deer”，实际名称是“bird”
# 第823张图片：预测名称是“airplane”，实际名称是“airplane”
# 第824张图片：预测名称是“ship”，实际名称是“ship”
# 第825张图片：预测名称是“horse”，实际名称是“horse”
# 第826张图片：预测名称是“cat”，实际名称是“cat”
# 第827张图片：预测名称是“horse”，实际名称是“horse”
# 第828张图片：预测名称是“frog”，实际名称是“frog”
# 第829张图片：预测名称是“dog”，实际名称是“dog”
# 第830张图片：预测名称是“cat”，实际名称是“cat”
# 第831张图片：预测名称是“automobile”，实际名称是“automobile”
# 第832张图片：预测名称是“truck”，实际名称是“cat”
# 第833张图片：预测名称是“bird”，实际名称是“bird”
# 第834张图片：预测名称是“bird”，实际名称是“bird”
# 第835张图片：预测名称是“bird”，实际名称是“dog”
# 第836张图片：预测名称是“deer”，实际名称是“deer”
# 第837张图片：预测名称是“automobile”，实际名称是“automobile”
# 第838张图片：预测名称是“bird”，实际名称是“bird”
# 第839张图片：预测名称是“truck”，实际名称是“truck”
# 第840张图片：预测名称是“bird”，实际名称是“bird”
# 第841张图片：预测名称是“horse”，实际名称是“horse”
# 第842张图片：预测名称是“ship”，实际名称是“airplane”
# 第843张图片：预测名称是“horse”，实际名称是“horse”
# 第844张图片：预测名称是“bird”，实际名称是“bird”
# 第845张图片：预测名称是“automobile”，实际名称是“automobile”
# 第846张图片：预测名称是“cat”，实际名称是“cat”
# 第847张图片：预测名称是“bird”，实际名称是“bird”
# 第848张图片：预测名称是“airplane”，实际名称是“airplane”
# 第849张图片：预测名称是“bird”，实际名称是“bird”
# 第850张图片：预测名称是“deer”，实际名称是“deer”
# 第851张图片：预测名称是“dog”，实际名称是“horse”
# 第852张图片：预测名称是“automobile”，实际名称是“truck”
# 第853张图片：预测名称是“ship”，实际名称是“ship”
# 第854张图片：预测名称是“automobile”，实际名称是“truck”
# 第855张图片：预测名称是“airplane”，实际名称是“airplane”
# 第856张图片：预测名称是“bird”，实际名称是“horse”
# 第857张图片：预测名称是“horse”，实际名称是“horse”
# 第858张图片：预测名称是“airplane”，实际名称是“airplane”
# 第859张图片：预测名称是“horse”，实际名称是“horse”
# 第860张图片：预测名称是“ship”，实际名称是“ship”
# 第861张图片：预测名称是“deer”，实际名称是“deer”
# 第862张图片：预测名称是“frog”，实际名称是“frog”
# 第863张图片：预测名称是“frog”，实际名称是“cat”
# 第864张图片：预测名称是“cat”，实际名称是“cat”
# 第865张图片：预测名称是“airplane”，实际名称是“airplane”
# 第866张图片：预测名称是“automobile”，实际名称是“automobile”
# 第867张图片：预测名称是“automobile”，实际名称是“cat”
# 第868张图片：预测名称是“horse”，实际名称是“horse”
# 第869张图片：预测名称是“airplane”，实际名称是“airplane”
# 第870张图片：预测名称是“automobile”，实际名称是“automobile”
# 第871张图片：预测名称是“cat”，实际名称是“cat”
# 第872张图片：预测名称是“automobile”，实际名称是“automobile”
# 第873张图片：预测名称是“deer”，实际名称是“deer”
# 第874张图片：预测名称是“bird”，实际名称是“bird”
# 第875张图片：预测名称是“cat”，实际名称是“cat”
# 第876张图片：预测名称是“ship”，实际名称是“ship”
# 第877张图片：预测名称是“deer”，实际名称是“deer”
# 第878张图片：预测名称是“bird”，实际名称是“bird”
# 第879张图片：预测名称是“bird”，实际名称是“cat”
# 第880张图片：预测名称是“horse”，实际名称是“horse”
# 第881张图片：预测名称是“ship”，实际名称是“ship”
# 第882张图片：预测名称是“deer”，实际名称是“deer”
# 第883张图片：预测名称是“airplane”，实际名称是“cat”
# 第884张图片：预测名称是“airplane”，实际名称是“airplane”
# 第885张图片：预测名称是“truck”，实际名称是“truck”
# 第886张图片：预测名称是“airplane”，实际名称是“airplane”
# 第887张图片：预测名称是“airplane”，实际名称是“airplane”
# 第888张图片：预测名称是“automobile”，实际名称是“automobile”
# 第889张图片：预测名称是“ship”，实际名称是“airplane”
# 第890张图片：预测名称是“frog”，实际名称是“deer”
# 第891张图片：预测名称是“deer”，实际名称是“deer”
# 第892张图片：预测名称是“frog”，实际名称是“frog”
# 第893张图片：预测名称是“horse”，实际名称是“horse”
# 第894张图片：预测名称是“frog”，实际名称是“frog”
# 第895张图片：预测名称是“automobile”，实际名称是“automobile”
# 第896张图片：预测名称是“automobile”，实际名称是“automobile”
# 第897张图片：预测名称是“cat”，实际名称是“cat”
# 第898张图片：预测名称是“horse”，实际名称是“horse”
# 第899张图片：预测名称是“horse”，实际名称是“cat”
# 第900张图片：预测名称是“dog”，实际名称是“dog”
# 第901张图片：预测名称是“frog”，实际名称是“bird”
# 第902张图片：预测名称是“frog”，实际名称是“frog”
# 第903张图片：预测名称是“frog”，实际名称是“frog”
# 第904张图片：预测名称是“dog”，实际名称是“dog”
# 第905张图片：预测名称是“ship”，实际名称是“ship”
# 第906张图片：预测名称是“horse”，实际名称是“horse”
# 第907张图片：预测名称是“automobile”，实际名称是“automobile”
# 第908张图片：预测名称是“frog”，实际名称是“frog”
# 第909张图片：预测名称是“ship”，实际名称是“ship”
# 第910张图片：预测名称是“ship”，实际名称是“ship”
# 第911张图片：预测名称是“dog”，实际名称是“dog”
# 第912张图片：预测名称是“cat”，实际名称是“cat”
# 第913张图片：预测名称是“bird”，实际名称是“airplane”
# 第914张图片：预测名称是“deer”，实际名称是“deer”
# 第915张图片：预测名称是“airplane”，实际名称是“airplane”
# 第916张图片：预测名称是“automobile”，实际名称是“automobile”
# 第917张图片：预测名称是“deer”，实际名称是“cat”
# 第918张图片：预测名称是“ship”，实际名称是“ship”
# 第919张图片：预测名称是“ship”，实际名称是“ship”
# 第920张图片：预测名称是“bird”，实际名称是“airplane”
# 第921张图片：预测名称是“frog”，实际名称是“frog”
# 第922张图片：预测名称是“truck”，实际名称是“truck”
# 第923张图片：预测名称是“truck”，实际名称是“truck”
# 第924张图片：预测名称是“truck”，实际名称是“truck”
# 第925张图片：预测名称是“dog”，实际名称是“dog”
# 第926张图片：预测名称是“cat”，实际名称是“dog”
# 第927张图片：预测名称是“ship”，实际名称是“ship”
# 第928张图片：预测名称是“bird”，实际名称是“frog”
# 第929张图片：预测名称是“airplane”，实际名称是“airplane”
# 第930张图片：预测名称是“airplane”，实际名称是“airplane”
# 第931张图片：预测名称是“deer”，实际名称是“deer”
# 第932张图片：预测名称是“bird”，实际名称是“bird”
# 第933张图片：预测名称是“cat”，实际名称是“cat”
# 第934张图片：预测名称是“bird”，实际名称是“bird”
# 第935张图片：预测名称是“horse”，实际名称是“horse”
# 第936张图片：预测名称是“bird”，实际名称是“bird”
# 第937张图片：预测名称是“bird”，实际名称是“bird”
# 第938张图片：预测名称是“dog”，实际名称是“dog”
# 第939张图片：预测名称是“truck”，实际名称是“truck”
# 第940张图片：预测名称是“ship”，实际名称是“ship”
# 第941张图片：预测名称是“truck”，实际名称是“truck”
# 第942张图片：预测名称是“automobile”，实际名称是“automobile”
# 第943张图片：预测名称是“horse”，实际名称是“horse”
# 第944张图片：预测名称是“deer”，实际名称是“deer”
# 第945张图片：预测名称是“airplane”，实际名称是“airplane”
# 第946张图片：预测名称是“dog”，实际名称是“cat”
# 第947张图片：预测名称是“airplane”，实际名称是“airplane”
# 第948张图片：预测名称是“automobile”，实际名称是“automobile”
# 第949张图片：预测名称是“dog”，实际名称是“cat”
# 第950张图片：预测名称是“ship”，实际名称是“ship”
# 第951张图片：预测名称是“cat”，实际名称是“cat”
# 第952张图片：预测名称是“truck”，实际名称是“truck”
# 第953张图片：预测名称是“frog”，实际名称是“frog”
# 第954张图片：预测名称是“automobile”，实际名称是“automobile”
# 第955张图片：预测名称是“deer”，实际名称是“deer”
# 第956张图片：预测名称是“horse”，实际名称是“horse”
# 第957张图片：预测名称是“bird”，实际名称是“airplane”
# 第958张图片：预测名称是“cat”，实际名称是“cat”
# 第959张图片：预测名称是“horse”，实际名称是“horse”
# 第960张图片：预测名称是“ship”，实际名称是“ship”
# 第961张图片：预测名称是“truck”，实际名称是“truck”
# 第962张图片：预测名称是“automobile”，实际名称是“automobile”
# 第963张图片：预测名称是“automobile”，实际名称是“automobile”
# 第964张图片：预测名称是“frog”，实际名称是“frog”
# 第965张图片：预测名称是“frog”，实际名称是“frog”
# 第966张图片：预测名称是“bird”，实际名称是“frog”
# 第967张图片：预测名称是“frog”，实际名称是“frog”
# 第968张图片：预测名称是“truck”，实际名称是“truck”
# 第969张图片：预测名称是“automobile”，实际名称是“automobile”
# 第970张图片：预测名称是“truck”，实际名称是“truck”
# 第971张图片：预测名称是“truck”，实际名称是“truck”
# 第972张图片：预测名称是“deer”，实际名称是“deer”
# 第973张图片：预测名称是“frog”，实际名称是“bird”
# 第974张图片：预测名称是“automobile”，实际名称是“automobile”
# 第975张图片：预测名称是“airplane”，实际名称是“horse”
# 第976张图片：预测名称是“airplane”，实际名称是“airplane”
# 第977张图片：预测名称是“frog”，实际名称是“frog”
# 第978张图片：预测名称是“ship”，实际名称是“ship”
# 第979张图片：预测名称是“truck”，实际名称是“automobile”
# 第980张图片：预测名称是“truck”，实际名称是“truck”
# 第981张图片：预测名称是“bird”，实际名称是“bird”
# 第982张图片：预测名称是“truck”，实际名称是“truck”
# 第983张图片：预测名称是“bird”，实际名称是“airplane”
# 第984张图片：预测名称是“deer”，实际名称是“deer”
# 第985张图片：预测名称是“horse”，实际名称是“horse”
# 第986张图片：预测名称是“ship”，实际名称是“ship”
# 第987张图片：预测名称是“cat”，实际名称是“cat”
# 第988张图片：预测名称是“automobile”，实际名称是“automobile”
# 第989张图片：预测名称是“bird”，实际名称是“bird”
# 第990张图片：预测名称是“airplane”，实际名称是“airplane”
# 第991张图片：预测名称是“automobile”，实际名称是“automobile”
# 第992张图片：预测名称是“cat”，实际名称是“dog”
# 第993张图片：预测名称是“ship”，实际名称是“ship”
# 第994张图片：预测名称是“horse”，实际名称是“deer”
# 第995张图片：预测名称是“bird”，实际名称是“frog”
# 第996张图片：预测名称是“bird”，实际名称是“cat”
# 第997张图片：预测名称是“ship”，实际名称是“ship”
# 第998张图片：预测名称是“truck”，实际名称是“automobile”
# 第999张图片：预测名称是“cat”，实际名称是“cat”
# 第1000张图片：预测名称是“ship”，实际名称是“ship”
# 第1001张图片：预测名称是“dog”，实际名称是“dog”
# 第1002张图片：预测名称是“ship”，实际名称是“airplane”
# 第1003张图片：预测名称是“ship”，实际名称是“ship”
# 第1004张图片：预测名称是“deer”，实际名称是“deer”
# 第1005张图片：预测名称是“ship”，实际名称是“ship”
# 第1006张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1007张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1008张图片：预测名称是“airplane”，实际名称是“ship”
# 第1009张图片：预测名称是“truck”，实际名称是“truck”
# 第1010张图片：预测名称是“frog”，实际名称是“frog”
# 第1011张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1012张图片：预测名称是“ship”，实际名称是“ship”
# 第1013张图片：预测名称是“frog”，实际名称是“frog”
# 第1014张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1015张图片：预测名称是“cat”，实际名称是“cat”
# 第1016张图片：预测名称是“deer”，实际名称是“deer”
# 第1017张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1018张图片：预测名称是“frog”，实际名称是“frog”
# 第1019张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1020张图片：预测名称是“dog”，实际名称是“dog”
# 第1021张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1022张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1023张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1024张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1025张图片：预测名称是“deer”，实际名称是“cat”
# 第1026张图片：预测名称是“dog”，实际名称是“dog”
# 第1027张图片：预测名称是“frog”，实际名称是“airplane”
# 第1028张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1029张图片：预测名称是“frog”，实际名称是“frog”
# 第1030张图片：预测名称是“frog”，实际名称是“frog”
# 第1031张图片：预测名称是“cat”，实际名称是“cat”
# 第1032张图片：预测名称是“cat”，实际名称是“cat”
# 第1033张图片：预测名称是“frog”，实际名称是“frog”
# 第1034张图片：预测名称是“cat”，实际名称是“cat”
# 第1035张图片：预测名称是“cat”，实际名称是“frog”
# 第1036张图片：预测名称是“cat”，实际名称是“frog”
# 第1037张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1038张图片：预测名称是“horse”，实际名称是“horse”
# 第1039张图片：预测名称是“bird”，实际名称是“bird”
# 第1040张图片：预测名称是“deer”，实际名称是“bird”
# 第1041张图片：预测名称是“bird”，实际名称是“horse”
# 第1042张图片：预测名称是“horse”，实际名称是“dog”
# 第1043张图片：预测名称是“bird”，实际名称是“dog”
# 第1044张图片：预测名称是“bird”，实际名称是“bird”
# 第1045张图片：预测名称是“ship”，实际名称是“ship”
# 第1046张图片：预测名称是“dog”，实际名称是“dog”
# 第1047张图片：预测名称是“frog”，实际名称是“bird”
# 第1048张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1049张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1050张图片：预测名称是“automobile”，实际名称是“deer”
# 第1051张图片：预测名称是“horse”，实际名称是“cat”
# 第1052张图片：预测名称是“frog”，实际名称是“bird”
# 第1053张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1054张图片：预测名称是“dog”，实际名称是“cat”
# 第1055张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1056张图片：预测名称是“dog”，实际名称是“dog”
# 第1057张图片：预测名称是“cat”，实际名称是“cat”
# 第1058张图片：预测名称是“horse”，实际名称是“horse”
# 第1059张图片：预测名称是“bird”，实际名称是“frog”
# 第1060张图片：预测名称是“ship”，实际名称是“ship”
# 第1061张图片：预测名称是“truck”，实际名称是“truck”
# 第1062张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1063张图片：预测名称是“frog”，实际名称是“frog”
# 第1064张图片：预测名称是“deer”，实际名称是“deer”
# 第1065张图片：预测名称是“truck”，实际名称是“truck”
# 第1066张图片：预测名称是“truck”，实际名称是“cat”
# 第1067张图片：预测名称是“automobile”，实际名称是“truck”
# 第1068张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1069张图片：预测名称是“truck”，实际名称是“truck”
# 第1070张图片：预测名称是“frog”，实际名称是“frog”
# 第1071张图片：预测名称是“cat”，实际名称是“cat”
# 第1072张图片：预测名称是“frog”，实际名称是“frog”
# 第1073张图片：预测名称是“ship”，实际名称是“airplane”
# 第1074张图片：预测名称是“horse”，实际名称是“horse”
# 第1075张图片：预测名称是“frog”，实际名称是“cat”
# 第1076张图片：预测名称是“ship”，实际名称是“ship”
# 第1077张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1078张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1079张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1080张图片：预测名称是“frog”，实际名称是“frog”
# 第1081张图片：预测名称是“frog”，实际名称是“frog”
# 第1082张图片：预测名称是“frog”，实际名称是“frog”
# 第1083张图片：预测名称是“truck”，实际名称是“truck”
# 第1084张图片：预测名称是“bird”，实际名称是“bird”
# 第1085张图片：预测名称是“bird”，实际名称是“dog”
# 第1086张图片：预测名称是“deer”，实际名称是“deer”
# 第1087张图片：预测名称是“horse”，实际名称是“deer”
# 第1088张图片：预测名称是“frog”，实际名称是“frog”
# 第1089张图片：预测名称是“cat”，实际名称是“cat”
# 第1090张图片：预测名称是“frog”，实际名称是“frog”
# 第1091张图片：预测名称是“ship”，实际名称是“airplane”
# 第1092张图片：预测名称是“ship”，实际名称是“ship”
# 第1093张图片：预测名称是“frog”，实际名称是“frog”
# 第1094张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1095张图片：预测名称是“cat”，实际名称是“frog”
# 第1096张图片：预测名称是“frog”，实际名称是“bird”
# 第1097张图片：预测名称是“horse”，实际名称是“horse”
# 第1098张图片：预测名称是“dog”，实际名称是“dog”
# 第1099张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1100张图片：预测名称是“bird”，实际名称是“bird”
# 第1101张图片：预测名称是“horse”，实际名称是“horse”
# 第1102张图片：预测名称是“ship”，实际名称是“ship”
# 第1103张图片：预测名称是“ship”，实际名称是“ship”
# 第1104张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1105张图片：预测名称是“truck”，实际名称是“truck”
# 第1106张图片：预测名称是“cat”，实际名称是“deer”
# 第1107张图片：预测名称是“truck”，实际名称是“truck”
# 第1108张图片：预测名称是“horse”，实际名称是“horse”
# 第1109张图片：预测名称是“bird”，实际名称是“bird”
# 第1110张图片：预测名称是“automobile”，实际名称是“airplane”
# 第1111张图片：预测名称是“bird”，实际名称是“bird”
# 第1112张图片：预测名称是“ship”，实际名称是“ship”
# 第1113张图片：预测名称是“bird”，实际名称是“cat”
# 第1114张图片：预测名称是“ship”，实际名称是“ship”
# 第1115张图片：预测名称是“truck”，实际名称是“truck”
# 第1116张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1117张图片：预测名称是“dog”，实际名称是“dog”
# 第1118张图片：预测名称是“dog”，实际名称是“dog”
# 第1119张图片：预测名称是“deer”，实际名称是“deer”
# 第1120张图片：预测名称是“horse”，实际名称是“horse”
# 第1121张图片：预测名称是“dog”，实际名称是“dog”
# 第1122张图片：预测名称是“cat”，实际名称是“cat”
# 第1123张图片：预测名称是“ship”，实际名称是“ship”
# 第1124张图片：预测名称是“cat”，实际名称是“cat”
# 第1125张图片：预测名称是“bird”，实际名称是“cat”
# 第1126张图片：预测名称是“frog”，实际名称是“frog”
# 第1127张图片：预测名称是“airplane”，实际名称是“bird”
# 第1128张图片：预测名称是“ship”，实际名称是“ship”
# 第1129张图片：预测名称是“deer”，实际名称是“deer”
# 第1130张图片：预测名称是“bird”，实际名称是“cat”
# 第1131张图片：预测名称是“truck”，实际名称是“horse”
# 第1132张图片：预测名称是“truck”，实际名称是“automobile”
# 第1133张图片：预测名称是“bird”，实际名称是“bird”
# 第1134张图片：预测名称是“deer”，实际名称是“deer”
# 第1135张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1136张图片：预测名称是“frog”，实际名称是“frog”
# 第1137张图片：预测名称是“truck”，实际名称是“truck”
# 第1138张图片：预测名称是“ship”，实际名称是“airplane”
# 第1139张图片：预测名称是“truck”，实际名称是“dog”
# 第1140张图片：预测名称是“ship”，实际名称是“ship”
# 第1141张图片：预测名称是“frog”，实际名称是“frog”
# 第1142张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1143张图片：预测名称是“ship”，实际名称是“ship”
# 第1144张图片：预测名称是“frog”，实际名称是“frog”
# 第1145张图片：预测名称是“airplane”，实际名称是“automobile”
# 第1146张图片：预测名称是“frog”，实际名称是“deer”
# 第1147张图片：预测名称是“deer”，实际名称是“bird”
# 第1148张图片：预测名称是“truck”，实际名称是“frog”
# 第1149张图片：预测名称是“bird”，实际名称是“bird”
# 第1150张图片：预测名称是“deer”，实际名称是“horse”
# 第1151张图片：预测名称是“horse”，实际名称是“bird”
# 第1152张图片：预测名称是“bird”，实际名称是“bird”
# 第1153张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1154张图片：预测名称是“ship”，实际名称是“ship”
# 第1155张图片：预测名称是“frog”，实际名称是“frog”
# 第1156张图片：预测名称是“truck”，实际名称是“truck”
# 第1157张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1158张图片：预测名称是“horse”，实际名称是“horse”
# 第1159张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1160张图片：预测名称是“ship”，实际名称是“ship”
# 第1161张图片：预测名称是“ship”，实际名称是“ship”
# 第1162张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1163张图片：预测名称是“horse”，实际名称是“horse”
# 第1164张图片：预测名称是“horse”，实际名称是“cat”
# 第1165张图片：预测名称是“truck”，实际名称是“ship”
# 第1166张图片：预测名称是“ship”，实际名称是“airplane”
# 第1167张图片：预测名称是“dog”，实际名称是“cat”
# 第1168张图片：预测名称是“deer”，实际名称是“deer”
# 第1169张图片：预测名称是“cat”，实际名称是“cat”
# 第1170张图片：预测名称是“horse”，实际名称是“horse”
# 第1171张图片：预测名称是“horse”，实际名称是“horse”
# 第1172张图片：预测名称是“truck”，实际名称是“truck”
# 第1173张图片：预测名称是“bird”，实际名称是“bird”
# 第1174张图片：预测名称是“cat”，实际名称是“cat”
# 第1175张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1176张图片：预测名称是“truck”，实际名称是“truck”
# 第1177张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1178张图片：预测名称是“automobile”，实际名称是“truck”
# 第1179张图片：预测名称是“bird”，实际名称是“frog”
# 第1180张图片：预测名称是“dog”，实际名称是“cat”
# 第1181张图片：预测名称是“cat”，实际名称是“cat”
# 第1182张图片：预测名称是“frog”，实际名称是“cat”
# 第1183张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1184张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1185张图片：预测名称是“frog”，实际名称是“frog”
# 第1186张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1187张图片：预测名称是“deer”，实际名称是“deer”
# 第1188张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1189张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1190张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1191张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1192张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1193张图片：预测名称是“frog”，实际名称是“frog”
# 第1194张图片：预测名称是“dog”，实际名称是“dog”
# 第1195张图片：预测名称是“deer”，实际名称是“deer”
# 第1196张图片：预测名称是“frog”，实际名称是“frog”
# 第1197张图片：预测名称是“bird”，实际名称是“bird”
# 第1198张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1199张图片：预测名称是“horse”，实际名称是“horse”
# 第1200张图片：预测名称是“truck”，实际名称是“truck”
# 第1201张图片：预测名称是“ship”，实际名称是“ship”
# 第1202张图片：预测名称是“horse”，实际名称是“horse”
# 第1203张图片：预测名称是“bird”，实际名称是“bird”
# 第1204张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1205张图片：预测名称是“frog”，实际名称是“frog”
# 第1206张图片：预测名称是“ship”，实际名称是“ship”
# 第1207张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1208张图片：预测名称是“ship”，实际名称是“deer”
# 第1209张图片：预测名称是“truck”，实际名称是“cat”
# 第1210张图片：预测名称是“horse”，实际名称是“horse”
# 第1211张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1212张图片：预测名称是“frog”，实际名称是“frog”
# 第1213张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1214张图片：预测名称是“ship”，实际名称是“ship”
# 第1215张图片：预测名称是“dog”，实际名称是“dog”
# 第1216张图片：预测名称是“horse”，实际名称是“horse”
# 第1217张图片：预测名称是“ship”，实际名称是“ship”
# 第1218张图片：预测名称是“deer”，实际名称是“deer”
# 第1219张图片：预测名称是“ship”，实际名称是“ship”
# 第1220张图片：预测名称是“cat”，实际名称是“cat”
# 第1221张图片：预测名称是“cat”，实际名称是“truck”
# 第1222张图片：预测名称是“truck”，实际名称是“truck”
# 第1223张图片：预测名称是“truck”，实际名称是“truck”
# 第1224张图片：预测名称是“airplane”，实际名称是“ship”
# 第1225张图片：预测名称是“deer”，实际名称是“horse”
# 第1226张图片：预测名称是“frog”，实际名称是“frog”
# 第1227张图片：预测名称是“frog”，实际名称是“frog”
# 第1228张图片：预测名称是“dog”，实际名称是“cat”
# 第1229张图片：预测名称是“cat”，实际名称是“dog”
# 第1230张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1231张图片：预测名称是“cat”，实际名称是“dog”
# 第1232张图片：预测名称是“truck”，实际名称是“truck”
# 第1233张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1234张图片：预测名称是“deer”，实际名称是“deer”
# 第1235张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1236张图片：预测名称是“dog”，实际名称是“dog”
# 第1237张图片：预测名称是“bird”，实际名称是“horse”
# 第1238张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1239张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1240张图片：预测名称是“dog”，实际名称是“dog”
# 第1241张图片：预测名称是“frog”，实际名称是“bird”
# 第1242张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1243张图片：预测名称是“ship”，实际名称是“ship”
# 第1244张图片：预测名称是“ship”，实际名称是“ship”
# 第1245张图片：预测名称是“cat”，实际名称是“dog”
# 第1246张图片：预测名称是“frog”，实际名称是“frog”
# 第1247张图片：预测名称是“dog”，实际名称是“horse”
# 第1248张图片：预测名称是“bird”，实际名称是“cat”
# 第1249张图片：预测名称是“deer”，实际名称是“bird”
# 第1250张图片：预测名称是“deer”，实际名称是“deer”
# 第1251张图片：预测名称是“horse”，实际名称是“horse”
# 第1252张图片：预测名称是“horse”，实际名称是“bird”
# 第1253张图片：预测名称是“dog”，实际名称是“dog”
# 第1254张图片：预测名称是“automobile”，实际名称是“ship”
# 第1255张图片：预测名称是“bird”，实际名称是“bird”
# 第1256张图片：预测名称是“deer”，实际名称是“deer”
# 第1257张图片：预测名称是“truck”，实际名称是“truck”
# 第1258张图片：预测名称是“bird”，实际名称是“bird”
# 第1259张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1260张图片：预测名称是“ship”，实际名称是“ship”
# 第1261张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1262张图片：预测名称是“truck”，实际名称是“truck”
# 第1263张图片：预测名称是“ship”，实际名称是“ship”
# 第1264张图片：预测名称是“ship”，实际名称是“ship”
# 第1265张图片：预测名称是“ship”，实际名称是“ship”
# 第1266张图片：预测名称是“truck”，实际名称是“truck”
# 第1267张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1268张图片：预测名称是“deer”，实际名称是“deer”
# 第1269张图片：预测名称是“bird”，实际名称是“cat”
# 第1270张图片：预测名称是“cat”，实际名称是“cat”
# 第1271张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1272张图片：预测名称是“ship”，实际名称是“ship”
# 第1273张图片：预测名称是“deer”，实际名称是“deer”
# 第1274张图片：预测名称是“deer”，实际名称是“frog”
# 第1275张图片：预测名称是“cat”，实际名称是“cat”
# 第1276张图片：预测名称是“cat”，实际名称是“cat”
# 第1277张图片：预测名称是“dog”，实际名称是“dog”
# 第1278张图片：预测名称是“bird”，实际名称是“bird”
# 第1279张图片：预测名称是“bird”，实际名称是“bird”
# 第1280张图片：预测名称是“truck”，实际名称是“ship”
# 第1281张图片：预测名称是“cat”，实际名称是“cat”
# 第1282张图片：预测名称是“ship”，实际名称是“ship”
# 第1283张图片：预测名称是“truck”，实际名称是“truck”
# 第1284张图片：预测名称是“dog”，实际名称是“dog”
# 第1285张图片：预测名称是“ship”，实际名称是“ship”
# 第1286张图片：预测名称是“automobile”，实际名称是“truck”
# 第1287张图片：预测名称是“ship”，实际名称是“ship”
# 第1288张图片：预测名称是“truck”，实际名称是“truck”
# 第1289张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1290张图片：预测名称是“frog”，实际名称是“frog”
# 第1291张图片：预测名称是“dog”，实际名称是“dog”
# 第1292张图片：预测名称是“truck”，实际名称是“truck”
# 第1293张图片：预测名称是“deer”，实际名称是“deer”
# 第1294张图片：预测名称是“deer”，实际名称是“deer”
# 第1295张图片：预测名称是“airplane”，实际名称是“ship”
# 第1296张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1297张图片：预测名称是“horse”，实际名称是“horse”
# 第1298张图片：预测名称是“airplane”，实际名称是“bird”
# 第1299张图片：预测名称是“truck”，实际名称是“truck”
# 第1300张图片：预测名称是“horse”，实际名称是“horse”
# 第1301张图片：预测名称是“deer”，实际名称是“deer”
# 第1302张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1303张图片：预测名称是“frog”，实际名称是“frog”
# 第1304张图片：预测名称是“deer”，实际名称是“deer”
# 第1305张图片：预测名称是“ship”，实际名称是“deer”
# 第1306张图片：预测名称是“truck”，实际名称是“truck”
# 第1307张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1308张图片：预测名称是“airplane”，实际名称是“bird”
# 第1309张图片：预测名称是“cat”，实际名称是“dog”
# 第1310张图片：预测名称是“bird”，实际名称是“frog”
# 第1311张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1312张图片：预测名称是“ship”，实际名称是“ship”
# 第1313张图片：预测名称是“frog”，实际名称是“frog”
# 第1314张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1315张图片：预测名称是“truck”，实际名称是“truck”
# 第1316张图片：预测名称是“bird”，实际名称是“deer”
# 第1317张图片：预测名称是“dog”，实际名称是“dog”
# 第1318张图片：预测名称是“truck”，实际名称是“truck”
# 第1319张图片：预测名称是“dog”，实际名称是“dog”
# 第1320张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1321张图片：预测名称是“horse”，实际名称是“horse”
# 第1322张图片：预测名称是“bird”，实际名称是“bird”
# 第1323张图片：预测名称是“truck”，实际名称是“airplane”
# 第1324张图片：预测名称是“truck”，实际名称是“airplane”
# 第1325张图片：预测名称是“deer”，实际名称是“deer”
# 第1326张图片：预测名称是“deer”，实际名称是“bird”
# 第1327张图片：预测名称是“frog”，实际名称是“frog”
# 第1328张图片：预测名称是“frog”，实际名称是“frog”
# 第1329张图片：预测名称是“dog”，实际名称是“dog”
# 第1330张图片：预测名称是“dog”，实际名称是“dog”
# 第1331张图片：预测名称是“bird”，实际名称是“bird”
# 第1332张图片：预测名称是“ship”，实际名称是“ship”
# 第1333张图片：预测名称是“truck”，实际名称是“automobile”
# 第1334张图片：预测名称是“horse”，实际名称是“horse”
# 第1335张图片：预测名称是“frog”，实际名称是“cat”
# 第1336张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1337张图片：预测名称是“deer”，实际名称是“deer”
# 第1338张图片：预测名称是“dog”，实际名称是“dog”
# 第1339张图片：预测名称是“frog”，实际名称是“frog”
# 第1340张图片：预测名称是“cat”，实际名称是“dog”
# 第1341张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1342张图片：预测名称是“deer”，实际名称是“deer”
# 第1343张图片：预测名称是“horse”，实际名称是“horse”
# 第1344张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1345张图片：预测名称是“truck”，实际名称是“truck”
# 第1346张图片：预测名称是“deer”，实际名称是“deer”
# 第1347张图片：预测名称是“frog”，实际名称是“cat”
# 第1348张图片：预测名称是“ship”，实际名称是“ship”
# 第1349张图片：预测名称是“bird”，实际名称是“bird”
# 第1350张图片：预测名称是“ship”，实际名称是“ship”
# 第1351张图片：预测名称是“frog”，实际名称是“deer”
# 第1352张图片：预测名称是“horse”，实际名称是“horse”
# 第1353张图片：预测名称是“bird”，实际名称是“bird”
# 第1354张图片：预测名称是“deer”，实际名称是“cat”
# 第1355张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1356张图片：预测名称是“cat”，实际名称是“dog”
# 第1357张图片：预测名称是“frog”，实际名称是“bird”
# 第1358张图片：预测名称是“truck”，实际名称是“truck”
# 第1359张图片：预测名称是“ship”，实际名称是“ship”
# 第1360张图片：预测名称是“truck”，实际名称是“truck”
# 第1361张图片：预测名称是“horse”，实际名称是“horse”
# 第1362张图片：预测名称是“truck”，实际名称是“truck”
# 第1363张图片：预测名称是“dog”，实际名称是“dog”
# 第1364张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1365张图片：预测名称是“deer”，实际名称是“deer”
# 第1366张图片：预测名称是“airplane”，实际名称是“airplane”
# 第1367张图片：预测名称是“ship”，实际名称是“ship”
# 第1368张图片：预测名称是“bird”，实际名称是“bird”
# 第1369张图片：预测名称是“cat”，实际名称是“cat”
# 第1370张图片：预测名称是“ship”，实际名称是“ship”
# 第1371张图片：预测名称是“truck”，实际名称是“truck”
# 第1372张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1373张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1374张图片：预测名称是“cat”，实际名称是“cat”
# 第1375张图片：预测名称是“airplane”，实际名称是“bird”
# 第1376张图片：预测名称是“deer”，实际名称是“deer”
# 第1377张图片：预测名称是“truck”，实际名称是“truck”
# 第1378张图片：预测名称是“dog”，实际名称是“cat”
# 第1379张图片：预测名称是“automobile”，实际名称是“automobile”
# 第1380张图片：预测名称是“horse”，实际名称是“horse”
# 第1381张图片：预测名称是“deer”，实际名称是“deer”
# 第1382张图片：预测名称是“frog”，实际名称是“frog”
# 第1383张图片：预测名称是“bird”，实际名称是“bird”
# 第1384张图片：预测名称是“deer”，实际名称是“ship”
# 第1385张图片：预测名称是“truck”，实际名称是“truck”
# 第1386张图片：预测名称是“dog”，实际名称是“dog”
# 第1387张图片：预测名称是“cat”，实际名称是“cat”
# 第1388张图片：预测名称是“truck”，实际名称是“truck”
# 第1389张图片：预测名称是“cat”，实际名称是“dog”
# 第1390张图片：预测名称是“deer”，实际名称是“dog”
# 第1391张图片：预测名称是“frog”，实际名称是“frog”
# 第1392张图片：预测名称是“bird”，实际名称是“horse”
# 第1393张图片：预测名称是“bird”，实际名称是“bird”
# 第1394张图片：预测名称是“deer”，实际名称是“deer”
# 第1395张图片：预测名称是“deer”，实际名称是“frog”
# 第1396张图片：预测名称是“cat”，实际名称是“cat”
# 第1397张图片：预测名称是“automobile”，实际名称是“automobile”
# ...
# 第9555张图片：预测名称是“horse”，实际名称是“horse”
# 第9556张图片：预测名称是“frog”，实际名称是“deer”
# 第9557张图片：预测名称是“frog”，实际名称是“frog”
# 第9558张图片：预测名称是“dog”，实际名称是“dog”
# 第9559张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9560张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9561张图片：预测名称是“truck”，实际名称是“truck”
# 第9562张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9563张图片：预测名称是“cat”，实际名称是“cat”
# 第9564张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9565张图片：预测名称是“truck”，实际名称是“truck”
# 第9566张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9567张图片：预测名称是“truck”，实际名称是“truck”
# 第9568张图片：预测名称是“horse”，实际名称是“horse”
# 第9569张图片：预测名称是“ship”，实际名称是“ship”
# 第9570张图片：预测名称是“frog”，实际名称是“frog”
# 第9571张图片：预测名称是“horse”，实际名称是“horse”
# 第9572张图片：预测名称是“frog”，实际名称是“frog”
# 第9573张图片：预测名称是“ship”，实际名称是“ship”
# 第9574张图片：预测名称是“dog”，实际名称是“bird”
# 第9575张图片：预测名称是“deer”，实际名称是“deer”
# 第9576张图片：预测名称是“cat”，实际名称是“dog”
# 第9577张图片：预测名称是“horse”，实际名称是“cat”
# 第9578张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9579张图片：预测名称是“cat”，实际名称是“cat”
# 第9580张图片：预测名称是“frog”，实际名称是“bird”
# 第9581张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9582张图片：预测名称是“horse”，实际名称是“horse”
# 第9583张图片：预测名称是“dog”，实际名称是“dog”
# 第9584张图片：预测名称是“truck”，实际名称是“truck”
# 第9585张图片：预测名称是“cat”，实际名称是“cat”
# 第9586张图片：预测名称是“deer”，实际名称是“deer”
# 第9587张图片：预测名称是“dog”，实际名称是“dog”
# 第9588张图片：预测名称是“truck”，实际名称是“horse”
# 第9589张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9590张图片：预测名称是“dog”，实际名称是“dog”
# 第9591张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9592张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9593张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9594张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9595张图片：预测名称是“truck”，实际名称是“truck”
# 第9596张图片：预测名称是“horse”，实际名称是“horse”
# 第9597张图片：预测名称是“cat”，实际名称是“dog”
# 第9598张图片：预测名称是“deer”，实际名称是“deer”
# 第9599张图片：预测名称是“truck”，实际名称是“truck”
# 第9600张图片：预测名称是“horse”，实际名称是“horse”
# 第9601张图片：预测名称是“ship”，实际名称是“ship”
# 第9602张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9603张图片：预测名称是“ship”，实际名称是“airplane”
# 第9604张图片：预测名称是“deer”，实际名称是“bird”
# 第9605张图片：预测名称是“ship”，实际名称是“ship”
# 第9606张图片：预测名称是“dog”，实际名称是“dog”
# 第9607张图片：预测名称是“frog”，实际名称是“frog”
# 第9608张图片：预测名称是“horse”，实际名称是“horse”
# 第9609张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9610张图片：预测名称是“deer”，实际名称是“automobile”
# 第9611张图片：预测名称是“deer”，实际名称是“deer”
# 第9612张图片：预测名称是“ship”，实际名称是“ship”
# 第9613张图片：预测名称是“airplane”，实际名称是“deer”
# 第9614张图片：预测名称是“deer”，实际名称是“deer”
# 第9615张图片：预测名称是“frog”，实际名称是“frog”
# 第9616张图片：预测名称是“frog”，实际名称是“frog”
# 第9617张图片：预测名称是“horse”，实际名称是“dog”
# 第9618张图片：预测名称是“ship”，实际名称是“ship”
# 第9619张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9620张图片：预测名称是“truck”，实际名称是“ship”
# 第9621张图片：预测名称是“deer”，实际名称是“deer”
# 第9622张图片：预测名称是“frog”，实际名称是“frog”
# 第9623张图片：预测名称是“horse”，实际名称是“dog”
# 第9624张图片：预测名称是“truck”，实际名称是“truck”
# 第9625张图片：预测名称是“bird”，实际名称是“bird”
# 第9626张图片：预测名称是“bird”，实际名称是“bird”
# 第9627张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9628张图片：预测名称是“deer”，实际名称是“deer”
# 第9629张图片：预测名称是“truck”，实际名称是“truck”
# 第9630张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9631张图片：预测名称是“frog”，实际名称是“frog”
# 第9632张图片：预测名称是“horse”，实际名称是“horse”
# 第9633张图片：预测名称是“bird”，实际名称是“bird”
# 第9634张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9635张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9636张图片：预测名称是“deer”，实际名称是“horse”
# 第9637张图片：预测名称是“frog”，实际名称是“frog”
# 第9638张图片：预测名称是“dog”，实际名称是“dog”
# 第9639张图片：预测名称是“bird”，实际名称是“bird”
# 第9640张图片：预测名称是“bird”，实际名称是“bird”
# 第9641张图片：预测名称是“dog”，实际名称是“dog”
# 第9642张图片：预测名称是“cat”，实际名称是“frog”
# 第9643张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9644张图片：预测名称是“automobile”，实际名称是“truck”
# 第9645张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9646张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9647张图片：预测名称是“horse”，实际名称是“dog”
# 第9648张图片：预测名称是“cat”，实际名称是“cat”
# 第9649张图片：预测名称是“cat”，实际名称是“cat”
# 第9650张图片：预测名称是“dog”，实际名称是“dog”
# 第9651张图片：预测名称是“ship”，实际名称是“ship”
# 第9652张图片：预测名称是“horse”，实际名称是“horse”
# 第9653张图片：预测名称是“dog”，实际名称是“dog”
# 第9654张图片：预测名称是“frog”，实际名称是“frog”
# 第9655张图片：预测名称是“horse”，实际名称是“dog”
# 第9656张图片：预测名称是“ship”，实际名称是“ship”
# 第9657张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9658张图片：预测名称是“cat”，实际名称是“dog”
# 第9659张图片：预测名称是“truck”，实际名称是“truck”
# 第9660张图片：预测名称是“deer”，实际名称是“deer”
# 第9661张图片：预测名称是“frog”，实际名称是“frog”
# 第9662张图片：预测名称是“bird”，实际名称是“dog”
# 第9663张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9664张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9665张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9666张图片：预测名称是“dog”，实际名称是“cat”
# 第9667张图片：预测名称是“bird”，实际名称是“cat”
# 第9668张图片：预测名称是“truck”，实际名称是“truck”
# 第9669张图片：预测名称是“horse”，实际名称是“deer”
# 第9670张图片：预测名称是“ship”，实际名称是“ship”
# 第9671张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9672张图片：预测名称是“horse”，实际名称是“horse”
# 第9673张图片：预测名称是“horse”，实际名称是“horse”
# 第9674张图片：预测名称是“truck”，实际名称是“truck”
# 第9675张图片：预测名称是“truck”，实际名称是“truck”
# 第9676张图片：预测名称是“deer”，实际名称是“deer”
# 第9677张图片：预测名称是“dog”，实际名称是“cat”
# 第9678张图片：预测名称是“frog”，实际名称是“frog”
# 第9679张图片：预测名称是“bird”，实际名称是“cat”
# 第9680张图片：预测名称是“bird”，实际名称是“bird”
# 第9681张图片：预测名称是“ship”，实际名称是“ship”
# 第9682张图片：预测名称是“bird”，实际名称是“bird”
# 第9683张图片：预测名称是“horse”，实际名称是“horse”
# 第9684张图片：预测名称是“frog”，实际名称是“frog”
# 第9685张图片：预测名称是“horse”，实际名称是“horse”
# 第9686张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9687张图片：预测名称是“bird”，实际名称是“bird”
# 第9688张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9689张图片：预测名称是“bird”，实际名称是“bird”
# 第9690张图片：预测名称是“truck”，实际名称是“truck”
# 第9691张图片：预测名称是“bird”，实际名称是“deer”
# 第9692张图片：预测名称是“frog”，实际名称是“frog”
# 第9693张图片：预测名称是“truck”，实际名称是“truck”
# 第9694张图片：预测名称是“frog”，实际名称是“frog”
# 第9695张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9696张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9697张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9698张图片：预测名称是“ship”，实际名称是“ship”
# 第9699张图片：预测名称是“horse”，实际名称是“horse”
# 第9700张图片：预测名称是“automobile”，实际名称是“airplane”
# 第9701张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9702张图片：预测名称是“deer”，实际名称是“deer”
# 第9703张图片：预测名称是“horse”，实际名称是“horse”
# 第9704张图片：预测名称是“deer”，实际名称是“deer”
# 第9705张图片：预测名称是“horse”，实际名称是“bird”
# 第9706张图片：预测名称是“frog”，实际名称是“frog”
# 第9707张图片：预测名称是“truck”，实际名称是“truck”
# 第9708张图片：预测名称是“horse”，实际名称是“dog”
# 第9709张图片：预测名称是“automobile”，实际名称是“truck”
# 第9710张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9711张图片：预测名称是“horse”，实际名称是“horse”
# 第9712张图片：预测名称是“deer”，实际名称是“deer”
# 第9713张图片：预测名称是“dog”，实际名称是“dog”
# 第9714张图片：预测名称是“ship”，实际名称是“ship”
# 第9715张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9716张图片：预测名称是“deer”，实际名称是“deer”
# 第9717张图片：预测名称是“dog”，实际名称是“horse”
# 第9718张图片：预测名称是“truck”，实际名称是“truck”
# 第9719张图片：预测名称是“truck”，实际名称是“truck”
# 第9720张图片：预测名称是“ship”，实际名称是“ship”
# 第9721张图片：预测名称是“frog”，实际名称是“ship”
# 第9722张图片：预测名称是“frog”，实际名称是“frog”
# 第9723张图片：预测名称是“deer”，实际名称是“cat”
# 第9724张图片：预测名称是“horse”，实际名称是“horse”
# 第9725张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9726张图片：预测名称是“ship”，实际名称是“ship”
# 第9727张图片：预测名称是“truck”，实际名称是“truck”
# 第9728张图片：预测名称是“bird”，实际名称是“frog”
# 第9729张图片：预测名称是“bird”，实际名称是“bird”
# 第9730张图片：预测名称是“frog”，实际名称是“deer”
# 第9731张图片：预测名称是“frog”，实际名称是“frog”
# 第9732张图片：预测名称是“frog”，实际名称是“bird”
# 第9733张图片：预测名称是“truck”，实际名称是“truck”
# 第9734张图片：预测名称是“horse”，实际名称是“horse”
# 第9735张图片：预测名称是“horse”，实际名称是“deer”
# 第9736张图片：预测名称是“frog”，实际名称是“frog”
# 第9737张图片：预测名称是“airplane”，实际名称是“ship”
# 第9738张图片：预测名称是“dog”，实际名称是“dog”
# 第9739张图片：预测名称是“frog”，实际名称是“frog”
# 第9740张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9741张图片：预测名称是“frog”，实际名称是“cat”
# 第9742张图片：预测名称是“dog”，实际名称是“dog”
# 第9743张图片：预测名称是“automobile”，实际名称是“truck”
# 第9744张图片：预测名称是“truck”，实际名称是“truck”
# 第9745张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9746张图片：预测名称是“frog”，实际名称是“cat”
# 第9747张图片：预测名称是“airplane”，实际名称是“bird”
# 第9748张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9749张图片：预测名称是“cat”，实际名称是“cat”
# 第9750张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9751张图片：预测名称是“deer”，实际名称是“bird”
# 第9752张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9753张图片：预测名称是“horse”，实际名称是“horse”
# 第9754张图片：预测名称是“cat”，实际名称是“cat”
# 第9755张图片：预测名称是“truck”，实际名称是“truck”
# 第9756张图片：预测名称是“cat”，实际名称是“cat”
# 第9757张图片：预测名称是“dog”，实际名称是“dog”
# 第9758张图片：预测名称是“horse”，实际名称是“horse”
# 第9759张图片：预测名称是“frog”，实际名称是“frog”
# 第9760张图片：预测名称是“dog”，实际名称是“dog”
# 第9761张图片：预测名称是“truck”，实际名称是“truck”
# 第9762张图片：预测名称是“dog”，实际名称是“dog”
# 第9763张图片：预测名称是“frog”，实际名称是“frog”
# 第9764张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9765张图片：预测名称是“bird”，实际名称是“bird”
# 第9766张图片：预测名称是“deer”，实际名称是“deer”
# 第9767张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9768张图片：预测名称是“deer”，实际名称是“bird”
# 第9769张图片：预测名称是“horse”，实际名称是“horse”
# 第9770张图片：预测名称是“ship”，实际名称是“ship”
# 第9771张图片：预测名称是“bird”，实际名称是“deer”
# 第9772张图片：预测名称是“deer”，实际名称是“deer”
# 第9773张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9774张图片：预测名称是“automobile”，实际名称是“truck”
# 第9775张图片：预测名称是“dog”，实际名称是“dog”
# 第9776张图片：预测名称是“truck”，实际名称是“truck”
# 第9777张图片：预测名称是“deer”，实际名称是“bird”
# 第9778张图片：预测名称是“horse”，实际名称是“truck”
# 第9779张图片：预测名称是“dog”，实际名称是“cat”
# 第9780张图片：预测名称是“cat”，实际名称是“bird”
# 第9781张图片：预测名称是“frog”，实际名称是“deer”
# 第9782张图片：预测名称是“cat”，实际名称是“cat”
# 第9783张图片：预测名称是“horse”，实际名称是“bird”
# 第9784张图片：预测名称是“frog”，实际名称是“bird”
# 第9785张图片：预测名称是“ship”，实际名称是“ship”
# 第9786张图片：预测名称是“ship”，实际名称是“ship”
# 第9787张图片：预测名称是“frog”，实际名称是“frog”
# 第9788张图片：预测名称是“ship”，实际名称是“ship”
# 第9789张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9790张图片：预测名称是“bird”，实际名称是“frog”
# 第9791张图片：预测名称是“automobile”，实际名称是“ship”
# 第9792张图片：预测名称是“airplane”，实际名称是“truck”
# 第9793张图片：预测名称是“automobile”，实际名称是“ship”
# 第9794张图片：预测名称是“dog”，实际名称是“bird”
# 第9795张图片：预测名称是“airplane”，实际名称是“automobile”
# 第9796张图片：预测名称是“deer”，实际名称是“deer”
# 第9797张图片：预测名称是“truck”，实际名称是“truck”
# 第9798张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9799张图片：预测名称是“dog”，实际名称是“dog”
# 第9800张图片：预测名称是“horse”，实际名称是“horse”
# 第9801张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9802张图片：预测名称是“dog”，实际名称是“frog”
# 第9803张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9804张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9805张图片：预测名称是“dog”，实际名称是“dog”
# 第9806张图片：预测名称是“airplane”，实际名称是“bird”
# 第9807张图片：预测名称是“ship”，实际名称是“ship”
# 第9808张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9809张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9810张图片：预测名称是“cat”，实际名称是“cat”
# 第9811张图片：预测名称是“ship”，实际名称是“ship”
# 第9812张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9813张图片：预测名称是“cat”，实际名称是“cat”
# 第9814张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9815张图片：预测名称是“ship”，实际名称是“ship”
# 第9816张图片：预测名称是“dog”，实际名称是“dog”
# 第9817张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9818张图片：预测名称是“automobile”，实际名称是“truck”
# 第9819张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9820张图片：预测名称是“dog”，实际名称是“cat”
# 第9821张图片：预测名称是“automobile”，实际名称是“airplane”
# 第9822张图片：预测名称是“frog”，实际名称是“deer”
# 第9823张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9824张图片：预测名称是“dog”，实际名称是“dog”
# 第9825张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9826张图片：预测名称是“deer”，实际名称是“bird”
# 第9827张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9828张图片：预测名称是“bird”，实际名称是“deer”
# 第9829张图片：预测名称是“truck”，实际名称是“truck”
# 第9830张图片：预测名称是“dog”，实际名称是“dog”
# 第9831张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9832张图片：预测名称是“bird”，实际名称是“bird”
# 第9833张图片：预测名称是“deer”，实际名称是“bird”
# 第9834张图片：预测名称是“horse”，实际名称是“horse”
# 第9835张图片：预测名称是“ship”，实际名称是“ship”
# 第9836张图片：预测名称是“horse”，实际名称是“horse”
# 第9837张图片：预测名称是“bird”，实际名称是“bird”
# 第9838张图片：预测名称是“deer”，实际名称是“deer”
# 第9839张图片：预测名称是“horse”，实际名称是“dog”
# 第9840张图片：预测名称是“frog”，实际名称是“cat”
# 第9841张图片：预测名称是“horse”，实际名称是“deer”
# 第9842张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9843张图片：预测名称是“deer”，实际名称是“frog”
# 第9844张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9845张图片：预测名称是“dog”，实际名称是“dog”
# 第9846张图片：预测名称是“truck”，实际名称是“truck”
# 第9847张图片：预测名称是“ship”，实际名称是“ship”
# 第9848张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9849张图片：预测名称是“bird”，实际名称是“bird”
# 第9850张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9851张图片：预测名称是“horse”，实际名称是“horse”
# 第9852张图片：预测名称是“frog”，实际名称是“frog”
# 第9853张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9854张图片：预测名称是“bird”，实际名称是“dog”
# 第9855张图片：预测名称是“truck”，实际名称是“truck”
# 第9856张图片：预测名称是“horse”，实际名称是“horse”
# 第9857张图片：预测名称是“dog”，实际名称是“dog”
# 第9858张图片：预测名称是“automobile”，实际名称是“airplane”
# 第9859张图片：预测名称是“frog”，实际名称是“deer”
# 第9860张图片：预测名称是“bird”，实际名称是“frog”
# 第9861张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9862张图片：预测名称是“frog”，实际名称是“frog”
# 第9863张图片：预测名称是“airplane”，实际名称是“cat”
# 第9864张图片：预测名称是“frog”，实际名称是“frog”
# 第9865张图片：预测名称是“ship”，实际名称是“ship”
# 第9866张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9867张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9868张图片：预测名称是“airplane”，实际名称是“ship”
# 第9869张图片：预测名称是“truck”，实际名称是“truck”
# 第9870张图片：预测名称是“horse”，实际名称是“horse”
# 第9871张图片：预测名称是“bird”，实际名称是“bird”
# 第9872张图片：预测名称是“truck”，实际名称是“truck”
# 第9873张图片：预测名称是“ship”，实际名称是“airplane”
# 第9874张图片：预测名称是“bird”，实际名称是“bird”
# 第9875张图片：预测名称是“bird”，实际名称是“bird”
# 第9876张图片：预测名称是“truck”，实际名称是“truck”
# 第9877张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9878张图片：预测名称是“frog”，实际名称是“frog”
# 第9879张图片：预测名称是“bird”，实际名称是“dog”
# 第9880张图片：预测名称是“cat”，实际名称是“horse”
# 第9881张图片：预测名称是“horse”，实际名称是“horse”
# 第9882张图片：预测名称是“truck”，实际名称是“truck”
# 第9883张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9884张图片：预测名称是“horse”，实际名称是“horse”
# 第9885张图片：预测名称是“truck”，实际名称是“truck”
# 第9886张图片：预测名称是“ship”，实际名称是“ship”
# 第9887张图片：预测名称是“deer”，实际名称是“deer”
# 第9888张图片：预测名称是“dog”，实际名称是“dog”
# 第9889张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9890张图片：预测名称是“ship”，实际名称是“ship”
# 第9891张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9892张图片：预测名称是“bird”，实际名称是“bird”
# 第9893张图片：预测名称是“cat”，实际名称是“dog”
# 第9894张图片：预测名称是“bird”，实际名称是“bird”
# 第9895张图片：预测名称是“airplane”，实际名称是“automobile”
# 第9896张图片：预测名称是“deer”，实际名称是“deer”
# 第9897张图片：预测名称是“deer”，实际名称是“deer”
# 第9898张图片：预测名称是“ship”，实际名称是“ship”
# 第9899张图片：预测名称是“truck”，实际名称是“truck”
# 第9900张图片：预测名称是“horse”，实际名称是“horse”
# 第9901张图片：预测名称是“ship”，实际名称是“ship”
# 第9902张图片：预测名称是“automobile”，实际名称是“cat”
# 第9903张图片：预测名称是“frog”，实际名称是“frog”
# 第9904张图片：预测名称是“frog”，实际名称是“frog”
# 第9905张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9906张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9907张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9908张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9909张图片：预测名称是“ship”，实际名称是“ship”
# 第9910张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9911张图片：预测名称是“horse”，实际名称是“deer”
# 第9912张图片：预测名称是“dog”，实际名称是“deer”
# 第9913张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9914张图片：预测名称是“horse”，实际名称是“horse”
# 第9915张图片：预测名称是“ship”，实际名称是“ship”
# 第9916张图片：预测名称是“bird”，实际名称是“bird”
# 第9917张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9918张图片：预测名称是“bird”，实际名称是“bird”
# 第9919张图片：预测名称是“truck”，实际名称是“dog”
# 第9920张图片：预测名称是“deer”，实际名称是“deer”
# 第9921张图片：预测名称是“frog”，实际名称是“frog”
# 第9922张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9923张图片：预测名称是“dog”，实际名称是“dog”
# 第9924张图片：预测名称是“horse”，实际名称是“horse”
# 第9925张图片：预测名称是“ship”，实际名称是“deer”
# 第9926张图片：预测名称是“deer”，实际名称是“deer”
# 第9927张图片：预测名称是“bird”，实际名称是“cat”
# 第9928张图片：预测名称是“truck”，实际名称是“truck”
# 第9929张图片：预测名称是“dog”，实际名称是“dog”
# 第9930张图片：预测名称是“ship”，实际名称是“ship”
# 第9931张图片：预测名称是“truck”，实际名称是“ship”
# 第9932张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9933张图片：预测名称是“ship”，实际名称是“ship”
# 第9934张图片：预测名称是“horse”，实际名称是“horse”
# 第9935张图片：预测名称是“deer”，实际名称是“deer”
# 第9936张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9937张图片：预测名称是“ship”，实际名称是“ship”
# 第9938张图片：预测名称是“deer”，实际名称是“deer”
# 第9939张图片：预测名称是“truck”，实际名称是“truck”
# 第9940张图片：预测名称是“dog”，实际名称是“dog”
# 第9941张图片：预测名称是“deer”，实际名称是“deer”
# 第9942张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9943张图片：预测名称是“horse”，实际名称是“horse”
# 第9944张图片：预测名称是“dog”，实际名称是“horse”
# 第9945张图片：预测名称是“horse”，实际名称是“horse”
# 第9946张图片：预测名称是“horse”，实际名称是“horse”
# 第9947张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9948张图片：预测名称是“bird”，实际名称是“cat”
# 第9949张图片：预测名称是“ship”，实际名称是“ship”
# 第9950张图片：预测名称是“horse”，实际名称是“cat”
# 第9951张图片：预测名称是“cat”，实际名称是“cat”
# 第9952张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9953张图片：预测名称是“dog”，实际名称是“dog”
# 第9954张图片：预测名称是“deer”，实际名称是“horse”
# 第9955张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9956张图片：预测名称是“ship”，实际名称是“ship”
# 第9957张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9958张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9959张图片：预测名称是“truck”，实际名称是“truck”
# 第9960张图片：预测名称是“bird”，实际名称是“bird”
# 第9961张图片：预测名称是“airplane”，实际名称是“bird”
# 第9962张图片：预测名称是“cat”，实际名称是“cat”
# 第9963张图片：预测名称是“horse”，实际名称是“deer”
# 第9964张图片：预测名称是“ship”，实际名称是“ship”
# 第9965张图片：预测名称是“bird”，实际名称是“bird”
# 第9966张图片：预测名称是“bird”，实际名称是“bird”
# 第9967张图片：预测名称是“frog”，实际名称是“frog”
# 第9968张图片：预测名称是“deer”，实际名称是“cat”
# 第9969张图片：预测名称是“dog”，实际名称是“cat”
# 第9970张图片：预测名称是“frog”，实际名称是“frog”
# 第9971张图片：预测名称是“bird”，实际名称是“bird”
# 第9972张图片：预测名称是“truck”，实际名称是“truck”
# 第9973张图片：预测名称是“deer”，实际名称是“deer”
# 第9974张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9975张图片：预测名称是“automobile”，实际名称是“automobile”
# 第9976张图片：预测名称是“horse”，实际名称是“horse”
# 第9977张图片：预测名称是“dog”，实际名称是“dog”
# 第9978张图片：预测名称是“cat”，实际名称是“dog”
# 第9979张图片：预测名称是“horse”，实际名称是“horse”
# 第9980张图片：预测名称是“cat”，实际名称是“cat”
# 第9981张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9982张图片：预测名称是“horse”，实际名称是“deer”
# 第9983张图片：预测名称是“frog”，实际名称是“bird”
# 第9984张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9985张图片：预测名称是“horse”，实际名称是“horse”
# 第9986张图片：预测名称是“dog”，实际名称是“dog”
# 第9987张图片：预测名称是“ship”，实际名称是“ship”
# 第9988张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9989张图片：预测名称是“ship”，实际名称是“ship”
# 第9990张图片：预测名称是“deer”，实际名称是“bird”
# 第9991张图片：预测名称是“horse”，实际名称是“horse”
# 第9992张图片：预测名称是“airplane”，实际名称是“airplane”
# 第9993张图片：预测名称是“cat”，实际名称是“cat”
# 第9994张图片：预测名称是“dog”，实际名称是“dog”
# 第9995张图片：预测名称是“cat”，实际名称是“cat”
# 第9996张图片：预测名称是“ship”，实际名称是“ship”
# 第9997张图片：预测名称是“cat”，实际名称是“cat”
# 第9998张图片：预测名称是“dog”，实际名称是“dog”
# 第9999张图片：预测名称是“automobile”，实际名称是“automobile”
# 第10000张图片：预测名称是“horse”，实际名称是“horse”
# Test Epoch: Acc@1: 78.01%: 100%|██████████| 20/20 [00:01<00:00, 10.01it/s]
# Test Accuracy: 78.01%
# 预测结果已保存到 test_results.csv
# Test Accuracy: 78.01%
